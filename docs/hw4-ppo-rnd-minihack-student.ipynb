# %% [markdown]
# # PPO and RND for MiniHack: Introduction

# %%
### BEGIN SOLUTION - Student's name
# --- --------
### END SOLUTION

### BEGIN SOLUTION - Message
# ALL_DONE - I have completed every task, and my solutions work correctly
### END SOLUTION

# %% [markdown]
# In this homework, we will explore [<b>Proximal Policy Optimization (PPO)</b>](https://arxiv.org/abs/1707.06347) combined with [<b>Random Network Distillation (RND)</b>](https://arxiv.org/abs/1810.12894) in the context of [MiniHack](https://github.com/facebookresearch/minihack) environments. These environments are challenging procedurally-generated tasks based on the [NetHack Learning Environment (NLE)](https://github.com/heiner/nle), designed to test advanced reinforcement learning algorithms. While PPO is a robust and popular policy optimization algorithm, RND introduces intrinsic rewards to encourage exploration in sparse-reward environments.
#
# The combination of PPO and RND addresses two key challenges in reinforcement learning:
# - <b>Sparse Rewards</b>: Many environments provide limited feedback, making it difficult for agents to learn effective policies. RND helps by providing intrinsic rewards based on prediction errors of a randomly initialized network, encouraging exploration.
# - <b>Efficient Policy Optimization</b>: PPO uses a clipped surrogate objective to ensure stable and efficient updates to the policy, preventing large deviations that could destabilize training.
#
# Submission requirements:
# * Please do not modify anything outside of the `### BEGIN SOLUTION ... ### END SOLUTION` blocks (if you feel it might be useful somewhere, ask on slack).
# * Don't use `tqdm.notebook` or `tqdm.auto`, just plain `tqdm`.
# * Don't use additional libraries than provided - see/run `hw4-rl_hw_tester_student` for reference.
# * Use only provided context objects and variables for each solution (common: numpy, torch) - example: (numpy, torch, self, x, action) - see/run `hw4-rl_hw_tester_student` for reference.
# * Include your full name in the designated solution field **Student\'s name** - **required**.
# * Use the designated solution field **Message** for additional information to assist the reviewing instructor - optional.
# * It should be possible to execute the notebook from top to bottom when loaded in Colab with a GPU in a reasonable amount of time (perfect solution about 2h).
# * Plots should either be images embedded in cell outputs (in a way that shows correctly when loading the notebook from the file, without executing it), or attached with the exported .ipynb notebook in a .zip file (screenshots are admissible, but prefer exporting with e.g. `plt.savefig()`). At the end of the notebook method `save_static_plots_in_notebook` will embed sufficient plots automatically.
# * Please submit your solution as a notebook with saved cell outputs.
# * There is one provided completed solution for reference which has its own test - `PPOT compute_advantages`.
# * **(IMPORTANT) Make sure that every correctly completed solution passes its designated test in `hw4-rl_hw_tester_student` notebook.**

# %% [markdown]
# ## Installation
# You will have to restart session on Google Colab
#
# (when configuring local env refer to local_config_instructions document)

# %%
# works for Google Colab
# !pip install tyro 
# !pip install imageio[ffmpeg]
# !pip install pufferlib==1.0
# !pip install --upgrade tensorboard
# !pip install "https://github.com/BartekCupial/nle/releases/download/fair/nle-0.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl"
# !pip install minihack

# %% [markdown]
# ### Alternative local installation tips
# (Ubuntu Linux)
#
# sudo apt update && sudo apt upgrade -y
#
# sudo apt install python3 python3-pip python3-venv build-essential cmake git -y \
# sudo apt install libffi-dev libbz2-dev liblzma-dev zlib1g-dev libncurses5-dev libncursesw5-dev -y \
# sudo apt install flex bison
#
# conda create -n rl_hw python=3.10 \
# conda activate rl_hw
#
# (in env)
#
# pip install tyro \
# pip install imageio[ffmpeg] \
# pip install pufferlib==1.0 \
# pip install --upgrade tensorboard \
# pip install minihack
#
# other libs can be installed via “conda install”

# %% [markdown]
# ## Imports

# %%
import random
import argparse
import time
from functools import partial
from collections import deque
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from gym.wrappers.normalize import RunningMeanStd
from torch.utils.tensorboard import SummaryWriter

# RL library for vectorized environments
import pufferlib
import pufferlib.vector
import pufferlib.emulation

# %% [markdown]
# ## Loggers

# %%
import plotly.graph_objects as go
import plotly.io as pio
import matplotlib.pyplot as plt
from google.colab import output # only for Google Colab
output.enable_custom_widget_manager()

class TrainingLolcaLogger:
    def __init__(self):
        self.loss = self.init_line_plot(title='Training entropy loss', xaxis_title='Global step')
        self.ave_er = self.init_line_plot(title='Training average episode return', xaxis_title='Global step')
        self.ave_cr = self.init_line_plot(title='Training average curiosity reward', xaxis_title='Global step')
        self.sps = self.init_line_plot(title='Steps Per Socond', xaxis_title='Global step')

        self.loss.data[0].name = f'PPO'
        self.loss.data[1].name = f'PPO+RND'
        self.ave_er.data[0].name = f'PPO'
        self.ave_er.data[1].name = f'PPO+RND'
        self.ave_cr.data[0].name = f'PPO+RND'
        self.sps.data[0].name = f'PPO'
        self.sps.data[1].name = f'PPO+RND'


    def init_line_plot(
        self,
        title,
        x=None, xaxis_title=None,
        yaxis_title=None, yaxis_type='linear',
        mode='lines'
    ):
        fig = go.Figure()
        fig.update_layout(
            title=title, title_x=0.5,
            xaxis_title=xaxis_title, yaxis_title=yaxis_title,
            height=400, width=1500, margin=dict(b=10, t=60)
        )
        fig.update_yaxes(type=yaxis_type)
        for _ in range(25):
            fig.add_trace(go.Scatter(x=[], y=[], showlegend=True, mode=mode))

        fig_widget = go.FigureWidget(fig)
        display(fig_widget)
        return fig_widget

    def plot_ppo_loss(self, loss, step):
        self.loss.data[0].y += (loss, )
        self.loss.data[0].x += (step, )

    def plot_rnd_loss(self, loss, step):
        self.loss.data[1].y += (loss, )
        self.loss.data[1].x += (step, )

    def plot_ppo_er(self, er, step):
        self.ave_er.data[0].y += (er, )
        self.ave_er.data[0].x += (step, )

    def plot_rnd_er(self, er, cr, step):
        self.ave_er.data[1].y += (er, )
        self.ave_er.data[1].x += (step, )
        self.ave_cr.data[0].y += (cr, )
        self.ave_cr.data[0].x += (step, )
    
    def plot_ppo_sps(self, sps, step):
        self.sps.data[0].y += (sps, )
        self.sps.data[0].x += (step, )
    
    def plot_rnd_sps(self, sps, step):
        self.sps.data[1].y += (sps, )
        self.sps.data[1].x += (step, )

    def save_static_plots_in_notebook(self):
        # Convert each FigureWidget to a regular Figure and display it using matplotlib
        static_loss = go.Figure(self.loss)
        static_ave_er = go.Figure(self.ave_er)
        static_ave_cr = go.Figure(self.ave_cr)
        static_sps = go.Figure(self.sps)

        # Plot loss
        plt.figure()
        for trace in static_loss.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Training entropy loss")
        plt.xlabel("Global step")
        plt.ylabel("Loss")
        plt.legend()
        plt.show()

        # Plot average episode return
        plt.figure()
        for trace in static_ave_er.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Training average episode return")
        plt.xlabel("Global step")
        plt.ylabel("Episode Return")
        plt.legend()
        plt.show()

        # Plot curiosity reward
        plt.figure()
        for trace in static_ave_cr.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Training average curiosity reward")
        plt.xlabel("Global step")
        plt.ylabel("Curiosity Reward")
        plt.legend()
        plt.show()

        # Plot SPS
        plt.figure()
        for trace in static_sps.data:
            plt.plot(trace.x, trace.y, label=trace.name)
        plt.title("Steps per socond")
        plt.xlabel("Global step")
        plt.ylabel("SPS")
        plt.legend()
        plt.show()


tlol = TrainingLolcaLogger()

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs --verbosity=1

# %% [markdown]
# ## Argument Parsing

# %%
def str2bool(v):
    if isinstance(v, bool):
        return v
    if isinstance(v, str) and v.lower() in ("true",):
        return True
    elif isinstance(v, str) and v.lower() in ("false",):
        return False
    else:
        raise argparse.ArgumentTypeError("Boolean value expected")


@dataclass
class Args:
    exp_name: str = "ppo_rnd"
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: str2bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: str2bool = True
    """if toggled, cuda will be enabled by default"""
    track: str2bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "cleanRL"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: str2bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""

    # Algorithm specific arguments
    env_id: str = "MiniHack-KeyRoom-Dark-S5-v0"
    """the id of the environment"""
    max_episode_steps: int = None
    """number of episode steps"""
    total_timesteps: int = 5000000
    """total timesteps of the experiments"""
    learning_rate: float = 2e-4
    """the learning rate of the optimizer"""
    num_envs: int = 128
    """the number of parallel game environments"""
    num_workers: int = 16
    """the number of workers"""
    num_steps: int = 128
    """the number of steps to run in each environment per policy rollout"""
    anneal_lr: str2bool = True
    """Toggle learning rate annealing for policy and value networks"""
    gamma: float = 0.999
    """the discount factor gamma"""
    gae_lambda: float = 0.95
    """the lambda for the general advantage estimation"""
    num_minibatches: int = 8
    """the number of mini-batches"""
    update_epochs: int = 8
    """the K epochs to update the policy"""
    norm_adv: str2bool = True
    """Toggles advantages normalization"""
    clip_coef: float = 0.1
    """the surrogate clipping coefficient"""
    clip_vloss: str2bool = True
    """Toggles whether or not to use a clipped loss for the value function, as per the paper."""
    ent_coef: float = 0.001
    """coefficient of the entropy"""
    vf_coef: float = 0.5
    """coefficient of the value function"""
    max_grad_norm: float = 40
    """the maximum norm for the gradient clipping"""
    target_kl: float = None
    """the target KL divergence threshold"""
    penalty_step: float = 0.0
    """the penalty for each env step"""
    value_bootstrap: str2bool = True
    """Value bootstrapping"""

    # RND arguments
    update_proportion: float = 1.0
    """proportion of exp used for predictor update"""
    int_coef: float = 0.1
    """coefficient of extrinsic reward"""
    ext_coef: float = 1.0
    """coefficient of intrinsic reward"""
    int_gamma: float = 0.99
    """Intrinsic reward discount rate"""
    num_iterations_obs_norm_init: int = 5
    """number of iterations to initialize the observations normalization parameters"""
    forward_coef: float = 0.1
    """weight on modelling loss (ie convergence of predictor)"""

    # to be filled in runtime
    batch_size: int = 0
    """the batch size (computed in runtime)"""
    minibatch_size: int = 0
    """the mini-batch size (computed in runtime)"""
    num_iterations: int = 0
    """the number of iterations (computed in runtime)"""

# %% [markdown]
# ## RecordEpisodeStatistics, RewardForwardFilter, layer_init

# %%
class RecordEpisodeStatistics:
    def __init__(self, env, deque_size=100):
        self.env = env
        self.num_envs = getattr(env, "num_envs", 1)
        self.episode_returns = None
        self.episode_lengths = None

    def __getattr__(self, name):
        return getattr(self.env, name)

    def reset(self, **kwargs):
        observations, infos = self.env.reset(**kwargs)
        self.episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        self.lives = np.zeros(self.num_envs, dtype=np.int32)
        self.returned_episode_returns = np.zeros(self.num_envs, dtype=np.float32)
        self.returned_episode_lengths = np.zeros(self.num_envs, dtype=np.int32)
        return observations, {}

    def step(self, action):
        observations, rewards, terminatedes, truncatedes, infos = self.env.step(action)
        self.episode_returns += rewards
        self.episode_lengths += 1
        self.returned_episode_returns[:] = self.episode_returns
        self.returned_episode_lengths[:] = self.episode_lengths
        self.episode_returns *= 1 - terminatedes
        self.episode_lengths *= 1 - terminatedes

        infos = {}
        infos["r"] = self.returned_episode_returns
        infos["l"] = self.returned_episode_lengths

        return (
            observations,
            rewards,
            terminatedes,
            truncatedes,
            infos,
        )


class RewardForwardFilter:
    def __init__(self, gamma):
        self.rewems = None
        self.gamma = gamma

    def update(self, rews):
        if self.rewems is None:
            self.rewems = rews
        else:
            self.rewems = self.rewems * self.gamma + rews
        return self.rewems


# ALGO LOGIC: initialize agent here:
def layer_init(layer, std=np.sqrt(2), bias_const=0.0):
    torch.nn.init.orthogonal_(layer.weight, std)
    torch.nn.init.constant_(layer.bias, bias_const)
    return layer

# %% [markdown]
# ## Create Envs

# %%
import gymnasium
from nle.env.base import NLE

class NLETimeLimit(gymnasium.Wrapper):
    def __init__(self, env: gymnasium.Env):
        super().__init__(env)

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        if "end_status" in info:  # Add safety check
            if info["end_status"] == NLE.StepStatus.ABORTED:
                truncated = True
        return obs, reward, terminated, truncated, info


def env_creator(args):
    '''NetHack binding creation function'''
    import minihack
    import gym
    import shimmy
    from pufferlib.environments.minihack.environment import MinihackWrapper, EXTRA_OBS_KEYS

    obs_key = minihack.base.MH_DEFAULT_OBS_KEYS + EXTRA_OBS_KEYS
    kwargs = dict(
        observation_keys=obs_key,
        penalty_step=args.penalty_step,
    )
    env = gym.make(args.env_id, **kwargs)
    env = shimmy.GymV21CompatibilityV0(env=env)
    env = NLETimeLimit(env)
    env = MinihackWrapper(env)
    return pufferlib.emulation.GymnasiumPufferEnv(env=env)

def create_env(args):
    env = pufferlib.vector.make(partial(env_creator, args), batch_size=args.num_envs, num_envs=args.num_envs, num_workers=args.num_workers, backend=pufferlib.vector.Multiprocessing)
    env = RecordEpisodeStatistics(env)
    return env

# %% [markdown]
# ## VideoRecorder

# %%
import imageio
import pathlib
from PIL import Image, ImageDraw, ImageFont
from IPython.display import Video


class VideoRecorder:
    def __init__(self, env, directory, size=(512, 512)):
        self.env = env
        self._directory = pathlib.Path(directory).expanduser()
        self._directory.mkdir(exist_ok=True, parents=True)
        self._size = size
        self._frames = None

    def __getattr__(self, name):
        return getattr(self.env, name)

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self._frames = [self.render_image()]
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        self._frames.append(self.render_image())

        if terminated or truncated:
            self._save()

        return obs, reward, terminated, truncated, info

    def _save(self):
        if self._frames:
            filename = str(self._directory / "trajectory.mp4")
            imageio.mimsave(filename, self._frames)

    def render_image(self):
        obs = self.env.env.env.gym_env.last_observation
        obs_keys = self.env.env.env.gym_env._observation_keys
        tty_chars = obs[obs_keys.index("tty_chars")]
        tty_colors = obs[obs_keys.index("tty_colors")]
        tty_cursor = obs[obs_keys.index("tty_cursor")]
        image = tty_render(tty_chars, tty_colors, tty_cursor, font_path=None)
        image = image.resize((600, 430))
        return np.asanyarray(image)


def tty_render(chars, colors, cursor=None, font_size=16, font_path="Hack-Regular.ttf"):
    # Create font object
    font = ImageFont.truetype(font_path, font_size) if font_path else ImageFont.load_default()

    height, width = chars.shape
    line_height = font_size + 6
    line_width = font_size - 6

    # Create image
    img = Image.new("RGB", (width * line_width, height * line_height), color="black")
    draw = ImageDraw.Draw(img)

    color_palette = [
        (0, 0, 0),
        (255, 0, 0),
        (0, 255, 0),
        (255, 255, 0),
        (0, 0, 255),
        (255, 0, 255),
        (0, 255, 255),
        (255, 255, 255),
    ]

    color_palette = [
        # Standard colors (30-37)
        (0, 0, 0),  # Black
        (255, 0, 0),  # Red
        (0, 255, 0),  # Green
        (255, 255, 0),  # Yellow
        (0, 0, 255),  # Blue
        (255, 0, 255),  # Magenta
        (0, 255, 255),  # Cyan
        (255, 255, 255),  # White
        # Bright colors (90-97)
        (128, 128, 128),  # Bright Black / Gray
        (255, 85, 85),  # Bright Red
        (85, 255, 85),  # Bright Green
        (255, 255, 85),  # Bright Yellow
        (85, 85, 255),  # Bright Blue
        (255, 85, 255),  # Bright Magenta
        (85, 255, 255),  # Bright Cyan
        (255, 255, 255),  # Bright White
    ]

    if cursor is None:
        cursor = (-1, -1)
    cursor = tuple(cursor)

    rows, cols = chars.shape
    y = 0
    for i in range(rows):
        x = 0
        for j in range(cols):
            draw.text((x, y), chr(chars[i, j]), fill=color_palette[colors[i, j] % 16], font=font)
            if cursor == (i, j):
                draw.text((x, y + 2), "_", fill=color_palette[7], font=font)

            x += line_width
        y += line_height

    return img


@torch.no_grad
def play(agent, args):
    env = env_creator(args)
    env = VideoRecorder(env, ".")
    obs, info = env.reset()

    device = next(agent.parameters()).device

    steps = 0
    reward = 0.0
    total_reward = 0.0

    while True:
        action = agent.get_action_and_value(torch.Tensor(obs).unsqueeze(0).to(device))[0][0].item()
        obs, reward, terminated, truncated, info = env.step(action)

        steps += 1
        total_reward += reward

        if not (terminated or truncated):
            continue

        break
    print(f"reward: {reward}, steps: {steps}")
    env.close()
    return info

# %% [markdown]
# # Task 1: PPO

# %% [markdown]
# ## Motivation
# Policy optimization methods in reinforcement learning face two major challenges: <b>sample inefficiency</b> and <b>training instability</b>. On-policy methods require fresh data collection for each policy update, making them sample inefficient since data cannot be reused once the policy changes. Additionally, early policy gradient approaches often suffered from instability during training, as large parameter updates could lead to performance collapse.
#
# <b>Trust Region Policy Optimization (TRPO)</b> attempted to address these issues by introducing constraints on policy updates. However, TRPO's reliance on complex second-order optimization made it computationally expensive and difficult to implement. This led to the development of <b>Proximal Policy Optimization (PPO)</b>, which maintains TRPO's benefits while simplifying the implementation.
#
# ## Core Idea
#
# The fundamental idea behind PPO is to prevent excessive policy changes during training by implementing a "clip" mechanism. This clipping function ensures that the ratio between new and old policies stays within a small range, typically $[1-\epsilon,1+\epsilon]$ where $\epsilon$ is usually between 0.1 and 0.2. When the policy update results in a ratio outside this range, the clipping function restricts the change, effectively creating a trust region without the computational complexity of second-order methods
#
#
# PPO operates in two main phases: data collection and optimization. During data collection, the algorithm gathers trajectories using the current policy. In the optimization phase, it performs multiple epochs of minibatch updates on this collected data. $\pi_{\theta_{old}(a_t|s_t)}$ are outputs of the actor when we collected the data, $\pi_{\theta_{old}(a_t|s_t)}$ are the outputs of the policy after we performed minibatch update.
#
# The PPO objective function is defined as:
#
# $$ L^{CLIP}(\theta)=\hat {\mathbb{E}}_t \left [ \min(r_t(\theta) \hat A_t, \text{clip}(r_t(\theta), 1-\epsilon, 1+\epsilon)\hat A_t) \right ] $$
#
# Here, $t$ indexes the time steps in the collected trajectories, $A_t$ denotes the estimated advantage function, and the probability ratio is defined as:
#
# $$r_t(\theta) = {\pi_\theta(a_t|s_t) \over \pi_{\theta_{old}}(a_t|s_t)}$$
#
# The hat over $A_t$ signifies that it is an **estimator** of the advantage function, and the hat over $E_t$ indicates an **empirical average** used to approximate the true expectation.
#
# The objective function maximizes the expected return by increasing the likelihood of actions with positive advantages ($A_t > 0$) while decreasing the likelihood of actions with negative advantages ($A_t < 0$). This balanced approach facilitates stable policy improvement. The expectation operator $\mathbb{E}_t$ indicates averaging over the sampled trajectories during data collection.
#
# ## Implementation Details
#
# 1. <b>Actor</b>: The actor represents the policy, $\pi_\theta(a_t|s_t)$, which maps states to a probability distribution over actions. It is responsible for deciding what action the agent should take in a given state. During training, the actor is updated to maximize the PPO objective function by either increasing or decreasing the likelihood of actions based on their estimated advantages.
#
# 2. <b>Critic</b>: The critic estimates the value of a state, typically using a value function $V_{\phi}(s_t)$. This value function helps determine how "good" a particular state is by predicting the expected cumulative reward from that state onward. The critic is trained to minimize the mean squared error between its predictions and the actual discounted returns observed during training.
#
# 3. <b>Data Collection</b>: In this phase, trajectories are collected by having the agent interact with the environment using its current policy $\pi_{\theta_{old}}(a_t|s_t)$. Each trajectory contains sequences of states, actions, rewards, and log probabilities of actions under the current policy. These trajectories are used to compute several key quantities:
#   - Discounted Returns: The cumulative rewards from each state onward.
#
#  $$ G_t = \sum_{t=0}^{∞} \gamma^t r_t $$
#  $$ G_t = \sum_{t=0}^k \gamma^t r_t + V_{\phi}(s_{k+1})  $$
#
#   - Advantages: The difference between observed returns and predicted state values. PPO uses Generalized Advantage Estimation (GAE) to compute these advantages efficiently and reduce variance.
#
#  $$ \hat{A}_t^{GAE(\gamma, \lambda)} = \sum_{l=0}^∞ (\gamma \lambda)^l \delta_{t+l}^V$$
#  $$\delta_t^V=-V(s_t) + r_t + \gamma V(s_{t+1})$$
#
# 4. <b>Optimization</b>: Once data is collected, PPO performs multiple epochs of minibatch updates on this data to improve both the actor (policy network) and the critic (value network). The optimization process involves:
#   - Policy Update (Actor): The PPO objective function is used to update the policy network.
#
#  $$ L^{CLIP}(\theta)=\hat {\mathbb{E}}_t \left [ \min(r_t(\theta) \hat A_t, \text{clip}(r_t(\theta), 1-\epsilon, 1+\epsilon)\hat A_t) \right ] $$
#
#   - Value Function Update (Critic): The critic network is updated by minimizing a mean squared error loss. Here, $G_t$ represents the discounted return or target value for state $s_t$
#
#  $$L^{VF}=\frac{1}{2N}\sum_{t=1}^{N}(V_{\phi}(s_t)-G_t)^2$$
#
#   - Entropy Regularization: To encourage exploration and prevent premature convergence to suboptimal policies, an entropy term is often added to the loss function.
#
#  $$L^{ENTROPY}=-\beta \sum_{\alpha} \pi_{\theta}(a|s) \text{log} \pi_{\theta}(a|s)$$
#
# ## Training Loop
# The overall training loop for PPO can be summarized as follows:
# - Collect trajectories using the current policy.
# - Compute discounted returns and advantages using GAE.
# - Perform multiple epochs of minibatch updates on both:
#   - The actor using the clipped surrogate objective.
#   - The critic using mean squared error loss.
# - Repeat until convergence or until a predefined number of iterations is reached.
#
# ## References
#
# - PPO: [J. Schulman et al., "Proximal Policy Optimization Algorithms." arXiv preprint arXiv:1707.06347, 2017.](https://arxiv.org/abs/1707.06347.pdf)
# - TRPO: [Schulman, John, et al. "Trust region policy optimization." International conference on machine learning. 2015.](http://proceedings.mlr.press/v37/schulman15.pdf)
# - GAE: [Schulman, John, et al. "High-dimensional continuous control using generalized advantage estimation."](https://arxiv.org/abs/1506.02438)

# %% [markdown]
# ## Implement Agent class
#
# We will use a shared encoder and three linear networks for the actor and two critics respectively. The encoder network consists of three parts:
# 1. A `blstats_net` that processes game statistics through an embedding layer,
# 2. A convolutional network (`chars_net`) that processes the game's character-based display after embedding each character,
# 3. A combination layer that merges and projects down these features.
#
# Projected features are then fed into three output heads:
# - actor that decides actions (policy),
# - critic that estimates extrinsic rewards (rewards from our environment),
# - critic that estimates intrinsic rewards (for curiosity-driven exploration).

# %%
class Agent(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.dtype = pufferlib.pytorch.nativize_dtype(env.emulated)

        self.blstats_net = nn.Sequential(
            nn.Embedding(256, 32),
            nn.Flatten(),
        )

        self.char_embed = nn.Embedding(256, 32)
        self.chars_net = nn.Sequential(
            layer_init(nn.Conv2d(32, 32, 5, stride=(2, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 5, stride=(1, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
        )

        self.proj = nn.Linear(864+960, 256)
        self.actor = layer_init(nn.Linear(256, env.single_action_space.n), std=0.01)
        self.critic_ext = layer_init(nn.Linear(256, 1), std=0.01)
        self.critic_int = layer_init(nn.Linear(256, 1), std=0.01)

    def encode_observations(self, x):
        x = x.type(torch.uint8) # Undo bad cleanrl cast
        x = pufferlib.pytorch.nativize_tensor(x, self.dtype)

        blstats = torch.clip(x['blstats'] + 1, 0, 255).int()
        blstats = self.blstats_net(blstats)

        chars = self.char_embed(x['chars'].int())
        chars = torch.permute(chars, (0, 3, 1, 2))
        chars = self.chars_net(chars)

        concat = torch.cat([blstats, chars], dim=1)
        return self.proj(concat)

    def get_action_and_value(self, x, action=None):
        # 1. encode the observations using the existing code
        # 2. pass this hidden state through the actor network to get action logits,
        # 3. create a torch.distributions.categorical.Categorical distribution from these logits
        # 4. either sample an action (if none is provided) or use the given action,
        # 5. The method should return a tuple containing:
        #     (
        #       the action,
        #       its log probability,
        #       the entropy of the distribution,
        #       and the values from both critic networks (extrinsic and intrinsic)
        #     ).
        ### BEGIN SOLUTION - PPO get_action_and_value

        ### END SOLUTION
        return (
            action,
            log_prob,
            entropy_prop,
            extrinsic_output,
            intrinsic_output
        )

    def get_value(self, x):
        # simply encode the observations and return the outputs of both critic networks (extrinsic and intrinsic).
        ### BEGIN SOLUTION - PPO get_value

        ### END SOLUTION
        return extrinsic_output, intrinsic_output

# %% [markdown]
# ## PPO Trainer

# %%
class PPOTrainer:
    def __init__(self, args, writer, env, agent, tlol:TrainingLolcaLogger):
        self.args = args
        self.writer = writer
        self.env = env
        self.agent = agent
        self.device = next(agent.parameters()).device
        self.tlol = tlol

        self.combined_parameters = list(self.agent.parameters())
        self.optimizer = optim.Adam(
            self.combined_parameters,
            lr=self.args.learning_rate,
            eps=1e-5,
        )

        self.obs = torch.zeros((self.args.num_steps, self.args.num_envs) + self.env.single_observation_space.shape).to(self.device)
        self.actions = torch.zeros((self.args.num_steps, self.args.num_envs) + self.env.single_action_space.shape).to(self.device)
        self.logprobs = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.rewards = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.dones = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.time_outs = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.ext_values = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)

        self.er_counter = 0
        self.av_er_interval = 20

    def compute_advantages(self, next_obs, next_done):
        """
        Your task is to implement the computation of advantages using Generalized Advantage Estimation (GAE).

        Key Concepts:
        - **Generalized Advantage Estimation (GAE):** A technique to compute advantage values that balances bias and variance
        using a combination of temporal difference (TD) errors and discounted returns.
        - **Temporal Difference Error (Delta):** Measures the difference between the predicted value and the observed reward
        plus the discounted value of the next state.
        - **Discount Factor (gamma):** Determines how much future rewards are taken into account.
        - **GAE Lambda (gae_lambda):** Controls the trade-off between bias and variance in advantage estimation.

        Available Variables:
        - `self.rewards`: A tensor containing rewards for each timestep in the trajectory.
        - `self.dones`: A tensor indicating whether each timestep is terminal.
        - `self.ext_values`: A tensor containing value estimates for each timestep in the trajectory.
        - `self.agent.get_value(obs)`: A method that returns the value estimate for a given observation.
        - `self.args.gamma`: The discount factor for future rewards.
        - `self.args.gae_lambda`: The GAE lambda parameter.

        Implementation Details:
        - Use a loop to iterate backward through time steps (`range(self.args.num_steps)`).
        - Compute temporal difference error (`delta`) at each step.
        - Use GAE to compute advantages recursively, starting from the last timestep.
        - Ensure that computations handle terminal states appropriately using `next_done` and `self.dones`.
        """

        with torch.no_grad():
            next_value_ext, _ = self.agent.get_value(next_obs)
            # Completed solution in studnet version
            ### BEGIN SOLUTION - PPOT compute_advantages
            next_value_ext = next_value_ext.reshape(1, -1)

            ext_advantages = torch.zeros_like(self.rewards, device=self.device)
            ext_lastgaelam = 0

            for t in reversed(range(self.args.num_steps)):
                if t == self.args.num_steps - 1:
                    ext_nextnonterminal = 1.0 - next_done
                    ext_nextvalues = next_value_ext
                else:
                    ext_nextnonterminal = 1.0 - self.dones[t + 1]
                    ext_nextvalues = self.ext_values[t + 1]

                ext_delta = (self.rewards[t] + self.args.gamma * ext_nextvalues * ext_nextnonterminal - self.ext_values[t])
                ext_advantages[t] = ext_lastgaelam = (ext_delta + self.args.gamma * self.args.gae_lambda * ext_nextnonterminal * ext_lastgaelam)
            ### END SOLUTION
        return ext_advantages

    def compute_policy_loss(self, mb_advantages, ratio):
        """
        Compute the clipped policy loss for Proximal Policy Optimization (PPO).

        Key Concepts:
        - PPO optimizes a policy by maximizing a clipped objective function to ensure stable training.
        This method computes the negative of that objective function to facilitate minimization, as 
        required by Torch optimization frameworks.
        - **Policy Ratio (ratio):** The ratio of the probability of taking an action under the current policy
        to the probability under the old policy. This measures how much the policy has changed.
        - **Clipping:** A technique to limit the change in the policy ratio to a range defined by `clip_coef`
        (e.g., [1 - clip_coef, 1 + clip_coef]). This prevents excessively large updates that can destabilize training.
        - **Advantages (mb_advantages):** Precomputed advantage values that guide the direction of policy updates.

        Available Variables:
        - `self.args.clip_coef`: The clipping coefficient used to limit changes in the policy ratio.

        Expected Output:
        - Return a scalar tensor representing the computed clipped policy loss. This loss is minimized to maximize the PPO objective.
        """
        ### BEGIN SOLUTION - PPOT compute_policy_loss

        ### END SOLUTION
        return pg_loss

    def compute_value_loss(self, new_values, returns):
        """
        Compute the value loss for a reinforcement learning agent.

        Key Concepts:
        - **Value Function:** A function that predicts the expected return (sum of future rewards) from a given state.

        Available Variables:
        - `new_values.view(-1)`: Reshape `new_values` into a flat tensor if necessary.
        - `returns`: Target returns for each timestep in the trajectory.

        Expected Output:
        - Return a scalar tensor `v_loss` representing the computed value loss.
        """
        ### BEGIN SOLUTION - PPOT compute_value_loss
        # Value loss
        
        ### END SOLUTION
        return v_loss

    def train(self):
        # ALGO Logic: Storage setup
        avg_returns = deque(maxlen=self.av_er_interval)

        # start the game
        global_step = 0
        start_time = time.time()
        next_obs = torch.Tensor(self.env.reset()[0]).to(self.device)
        next_done = torch.zeros(self.args.num_envs).to(self.device)
        next_time_out = torch.zeros(self.args.num_envs).to(self.device)
        num_updates = self.args.total_timesteps // self.args.batch_size

        for update in range(1, num_updates + 1):
            # Annealing the rate if instructed to do so.
            if self.args.anneal_lr:
                frac = 1.0 - (update - 1.0) / num_updates
                lrnow = frac * self.args.learning_rate
                self.optimizer.param_groups[0]["lr"] = lrnow

            for step in range(0, self.args.num_steps):
                global_step += 1 * self.args.num_envs
                self.obs[step] = next_obs
                self.dones[step] = next_done
                self.time_outs[step] = next_time_out

                # ALGO LOGIC: action logic
                with torch.no_grad():
                    value_ext, _ = self.agent.get_value(self.obs[step])
                    self.ext_values[step] = value_ext.flatten()
                    action, logprob, _, _, _ = self.agent.get_action_and_value(self.obs[step])

                self.actions[step] = action
                self.logprobs[step] = logprob

                # execute the game and log data.
                next_obs, reward, terminated, truncated, info = self.env.step(action.cpu().numpy())
                self.rewards[step] = torch.tensor(reward).to(self.device).view(-1)
                next_obs = torch.Tensor(next_obs).to(self.device)
                next_done = torch.Tensor(terminated).to(self.device)
                next_time_out = torch.Tensor(truncated).to(self.device)

                local_step = global_step - 1 * self.args.num_envs
                for idx, d in enumerate(terminated | truncated):
                    local_step+=1
                    if d:
                        avg_returns.append(info["r"][idx])
                        epi_ret = np.average(avg_returns)
                        epi_suc = np.average([1 if r > 0 else 0 for r in avg_returns])
                        if self.er_counter >= self.av_er_interval:
                            self.er_counter = 0
                            print(
                                f"local_step={local_step}, {self.av_er_interval}_avg_episodic_return={epi_ret}"
                            )
                            tlol.plot_ppo_er(epi_ret, local_step)
                        else:
                            self.er_counter += 1
                        self.writer.add_scalar("charts/avg_success_rate", epi_suc, local_step)
                        self.writer.add_scalar("charts/avg_episodic_return", epi_ret, local_step)
                        self.writer.add_scalar("charts/episodic_return", info["r"][idx], local_step)
                        self.writer.add_scalar("charts/episodic_length", info["l"][idx], local_step)

            if self.args.value_bootstrap:
                # Value bootstrapping is a technique that reduces the surprise for the critic in case
                # we're ending the episode by timeout. Intuitively, in this case the cumulative return for the last step
                # should not be zero, but rather what the critic expects. This improves learning in many envs
                # because otherwise the critic cannot predict the abrupt change in rewards in a timed-out episode.
                # What we really want here is v(t+1) which we don't have because we don't have obs(t+1) (since
                # the episode ended). Using v(t) is an approximation that requires that rew(t) can be generally ignored.
                self.rewards.add_(self.args.gamma * self.ext_values * self.time_outs)

            # bootstrap value if not done
            with torch.no_grad():
                ext_advantages = self.compute_advantages(next_obs, next_done)
                ext_returns = ext_advantages + self.ext_values

            # flatten the batch
            b_obs = self.obs.reshape((-1,) + self.env.single_observation_space.shape)
            b_logprobs = self.logprobs.reshape(-1)
            b_actions = self.actions.reshape(-1)
            b_ext_advantages = ext_advantages.reshape(-1)
            b_ext_returns = ext_returns.reshape(-1)

            b_advantages = b_ext_advantages * self.args.ext_coef

            # Optimizing the policy and value network
            b_inds = np.arange(self.args.batch_size)

            clipfracs = []
            for epoch in range(self.args.update_epochs):
                np.random.shuffle(b_inds)
                for start in range(0, self.args.batch_size, self.args.minibatch_size):
                    end = start + self.args.minibatch_size
                    mb_inds = b_inds[start:end]

                    _, newlogprob, entropy, new_ext_values, _ = self.agent.get_action_and_value(
                        b_obs[mb_inds], b_actions.long()[mb_inds]
                    )
                    logratio = newlogprob - b_logprobs[mb_inds]
                    ratio = logratio.exp()

                    with torch.no_grad():
                        # calculate approx_kl http://joschu.net/blog/kl-approx.html
                        old_approx_kl = (-logratio).mean()
                        approx_kl = ((ratio - 1) - logratio).mean()
                        clipfracs += [((ratio - 1.0).abs() > self.args.clip_coef).float().mean().item()]

                    mb_advantages = b_advantages[mb_inds]
                    if self.args.norm_adv:
                        mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                    # Policy loss
                    pg_loss = self.compute_policy_loss(mb_advantages, ratio)

                    # Value loss
                    v_loss = self.compute_value_loss(new_ext_values, b_ext_returns[mb_inds])

                    # Entropy loss
                    entropy_loss = entropy.mean()
                    loss = pg_loss - self.args.ent_coef * entropy_loss + v_loss * self.args.vf_coef

                    self.optimizer.zero_grad()
                    loss.backward()
                    if self.args.max_grad_norm:
                        nn.utils.clip_grad_norm_(
                            self.combined_parameters,
                            self.args.max_grad_norm,
                        )
                    self.optimizer.step()

                if self.args.target_kl is not None:
                    if approx_kl > self.args.target_kl:
                        break

            # record rewards for plotting purposes
            self.writer.add_scalar("charts/learning_rate", self.optimizer.param_groups[0]["lr"], global_step)
            self.writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
            self.writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
            self.writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
            self.tlol.plot_ppo_loss(entropy_loss.item(), global_step)
            self.writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
            self.writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
            # print("SPS:", int(global_step / (time.time() - start_time))) # Uncomment if you want to estimate your training speed - should be around 50 and the beginning and 200+ later steps per second on Colab
            self.tlol.plot_ppo_sps(int(global_step / (time.time() - start_time)), global_step)
            self.writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

# %%
args = Args(
    num_steps=32,
    num_workers=8,
    num_envs=128,
    env_id="MiniHack-KeyRoom-S5-v0",
    total_timesteps=1_000_000,
)

# %%
args.batch_size = int(args.num_envs * args.num_steps)
args.minibatch_size = int(args.batch_size // args.num_minibatches)
args.num_iterations = args.total_timesteps // args.batch_size
run_name = f"{args.env_id}__ppo__{args.seed}__{int(time.time())}"

writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
env = create_env(args)

agent = Agent(env).to(device)

trainer = PPOTrainer(args, writer, env, agent, tlol)
trainer.train()

env.close()
writer.close()

play(agent, args)
Video("trajectory.mp4", embed=True)
# Out:
# local_step=25484, 20_avg_episodic_return=0.44999998807907104
# local_step=25507, 20_avg_episodic_return=0.0
# local_step=25532, 20_avg_episodic_return=0.0
# local_step=25553, 20_avg_episodic_return=0.0
# local_step=25574, 20_avg_episodic_return=0.0
# local_step=25597, 20_avg_episodic_return=0.0
# local_step=46762, 20_avg_episodic_return=0.699999988079071
# local_step=51212, 20_avg_episodic_return=0.3499999940395355
# local_step=51245, 20_avg_episodic_return=0.0
# local_step=51270, 20_avg_episodic_return=0.0
# local_step=51297, 20_avg_episodic_return=0.0
# local_step=51323, 20_avg_episodic_return=0.0
# local_step=66473, 20_avg_episodic_return=0.550000011920929
# local_step=73855, 20_avg_episodic_return=0.44999998807907104
# local_step=76945, 20_avg_episodic_return=0.25
# local_step=76986, 20_avg_episodic_return=0.0
# local_step=77013, 20_avg_episodic_return=0.0
# local_step=77043, 20_avg_episodic_return=0.0
# local_step=84958, 20_avg_episodic_return=0.30000001192092896
# local_step=94358, 20_avg_episodic_return=0.5
# local_step=99229, 20_avg_episodic_return=0.4000000059604645
# local_step=102670, 20_avg_episodic_return=0.05000000074505806
# local_step=102718, 20_avg_episodic_return=0.0
# local_step=102751, 20_avg_episodic_return=0.0
# local_step=105314, 20_avg_episodic_return=0.20000000298023224
# local_step=114273, 20_avg_episodic_return=0.25
# local_step=120584, 20_avg_episodic_return=0.30000001192092896
# local_step=124173, 20_avg_episodic_return=0.4000000059604645
# local_step=128393, 20_avg_episodic_return=0.3499999940395355
# local_step=128451, 20_avg_episodic_return=0.05000000074505806
# local_step=128503, 20_avg_episodic_return=0.0
# local_step=135337, 20_avg_episodic_return=0.30000001192092896
# local_step=140888, 20_avg_episodic_return=0.44999998807907104
# local_step=146312, 20_avg_episodic_return=0.4000000059604645
# local_step=149546, 20_avg_episodic_return=0.4000000059604645
# local_step=153153, 20_avg_episodic_return=0.30000001192092896
# local_step=154178, 20_avg_episodic_return=0.0
# local_step=157167, 20_avg_episodic_return=0.05000000074505806
# local_step=162480, 20_avg_episodic_return=0.3499999940395355
# local_step=167647, 20_avg_episodic_return=0.30000001192092896
# local_step=172124, 20_avg_episodic_return=0.3499999940395355
# local_step=174967, 20_avg_episodic_return=0.44999998807907104
# local_step=177387, 20_avg_episodic_return=0.20000000298023224
# local_step=179897, 20_avg_episodic_return=0.15000000596046448
# local_step=181460, 20_avg_episodic_return=0.25
# local_step=186832, 20_avg_episodic_return=0.4000000059604645
# local_step=191457, 20_avg_episodic_return=0.6499999761581421
# local_step=196774, 20_avg_episodic_return=0.44999998807907104
# local_step=200185, 20_avg_episodic_return=0.25
# local_step=202418, 20_avg_episodic_return=0.3499999940395355
# local_step=205588, 20_avg_episodic_return=0.25
# local_step=207212, 20_avg_episodic_return=0.10000000149011612
# local_step=211653, 20_avg_episodic_return=0.44999998807907104
# local_step=217185, 20_avg_episodic_return=0.15000000596046448
# local_step=222502, 20_avg_episodic_return=0.5
# local_step=225969, 20_avg_episodic_return=0.25
# local_step=228054, 20_avg_episodic_return=0.3499999940395355
# local_step=231306, 20_avg_episodic_return=0.15000000596046448
# local_step=232603, 20_avg_episodic_return=0.20000000298023224
# local_step=237517, 20_avg_episodic_return=0.20000000298023224
# local_step=243983, 20_avg_episodic_return=0.25
# local_step=248422, 20_avg_episodic_return=0.25
# local_step=251641, 20_avg_episodic_return=0.30000001192092896
# local_step=254101, 20_avg_episodic_return=0.10000000149011612
# local_step=257034, 20_avg_episodic_return=0.4000000059604645
# local_step=258331, 20_avg_episodic_return=0.10000000149011612
# local_step=263049, 20_avg_episodic_return=0.30000001192092896
# local_step=267827, 20_avg_episodic_return=0.6000000238418579
# local_step=272792, 20_avg_episodic_return=0.3499999940395355
# local_step=276489, 20_avg_episodic_return=0.4000000059604645
# local_step=278745, 20_avg_episodic_return=0.20000000298023224
# local_step=280851, 20_avg_episodic_return=0.25
# local_step=282887, 20_avg_episodic_return=0.25
# local_step=287832, 20_avg_episodic_return=0.5
# local_step=292021, 20_avg_episodic_return=0.44999998807907104
# local_step=296287, 20_avg_episodic_return=0.3499999940395355
# local_step=299878, 20_avg_episodic_return=0.44999998807907104
# local_step=303243, 20_avg_episodic_return=0.44999998807907104
# local_step=305787, 20_avg_episodic_return=0.15000000596046448
# local_step=308281, 20_avg_episodic_return=0.44999998807907104
# local_step=311759, 20_avg_episodic_return=0.25
# local_step=315526, 20_avg_episodic_return=0.3499999940395355
# local_step=319544, 20_avg_episodic_return=0.3499999940395355
# local_step=323721, 20_avg_episodic_return=0.6000000238418579
# local_step=326714, 20_avg_episodic_return=0.25
# local_step=330201, 20_avg_episodic_return=0.30000001192092896
# local_step=332388, 20_avg_episodic_return=0.30000001192092896
# local_step=334307, 20_avg_episodic_return=0.3499999940395355
# local_step=337916, 20_avg_episodic_return=0.550000011920929
# local_step=340552, 20_avg_episodic_return=0.550000011920929
# local_step=343103, 20_avg_episodic_return=0.6000000238418579
# local_step=345272, 20_avg_episodic_return=0.6000000238418579
# local_step=349622, 20_avg_episodic_return=0.550000011920929
# local_step=353328, 20_avg_episodic_return=0.4000000059604645
# local_step=356698, 20_avg_episodic_return=0.44999998807907104
# local_step=359956, 20_avg_episodic_return=0.44999998807907104
# local_step=363575, 20_avg_episodic_return=0.4000000059604645
# local_step=366004, 20_avg_episodic_return=0.44999998807907104
# local_step=368506, 20_avg_episodic_return=0.44999998807907104
# local_step=370227, 20_avg_episodic_return=0.4000000059604645
# local_step=373915, 20_avg_episodic_return=0.6000000238418579
# local_step=376325, 20_avg_episodic_return=0.6000000238418579
# local_step=378679, 20_avg_episodic_return=0.800000011920929
# local_step=381183, 20_avg_episodic_return=0.699999988079071
# local_step=383978, 20_avg_episodic_return=0.5
# local_step=387054, 20_avg_episodic_return=0.699999988079071
# local_step=389550, 20_avg_episodic_return=0.75
# local_step=391625, 20_avg_episodic_return=0.6000000238418579
# local_step=393781, 20_avg_episodic_return=0.5
# local_step=396878, 20_avg_episodic_return=0.4000000059604645
# local_step=399033, 20_avg_episodic_return=0.8500000238418579
# local_step=402169, 20_avg_episodic_return=0.5
# local_step=403940, 20_avg_episodic_return=0.800000011920929
# local_step=406477, 20_avg_episodic_return=0.6499999761581421
# local_step=408698, 20_avg_episodic_return=0.75
# local_step=410729, 20_avg_episodic_return=0.800000011920929
# local_step=413101, 20_avg_episodic_return=0.6000000238418579
# local_step=415781, 20_avg_episodic_return=0.550000011920929
# local_step=417849, 20_avg_episodic_return=0.75
# local_step=419619, 20_avg_episodic_return=0.6499999761581421
# local_step=422755, 20_avg_episodic_return=0.800000011920929
# local_step=425769, 20_avg_episodic_return=0.6499999761581421
# local_step=427344, 20_avg_episodic_return=0.8500000238418579
# local_step=429732, 20_avg_episodic_return=0.6000000238418579
# local_step=431250, 20_avg_episodic_return=0.75
# local_step=434583, 20_avg_episodic_return=0.5
# local_step=436019, 20_avg_episodic_return=0.8500000238418579
# local_step=438251, 20_avg_episodic_return=0.8500000238418579
# local_step=440217, 20_avg_episodic_return=0.8500000238418579
# local_step=442480, 20_avg_episodic_return=0.6499999761581421
# local_step=444135, 20_avg_episodic_return=0.6000000238418579
# local_step=446181, 20_avg_episodic_return=0.8500000238418579
# local_step=448455, 20_avg_episodic_return=0.75
# local_step=450446, 20_avg_episodic_return=0.75
# local_step=451796, 20_avg_episodic_return=0.8999999761581421
# local_step=453587, 20_avg_episodic_return=0.8999999761581421
# local_step=454926, 20_avg_episodic_return=0.8500000238418579
# local_step=456197, 20_avg_episodic_return=0.6000000238418579
# local_step=458630, 20_avg_episodic_return=1.0
# local_step=460918, 20_avg_episodic_return=0.949999988079071
# local_step=462470, 20_avg_episodic_return=0.5
# local_step=464557, 20_avg_episodic_return=0.75
# local_step=466048, 20_avg_episodic_return=0.800000011920929
# local_step=467929, 20_avg_episodic_return=0.800000011920929
# local_step=469690, 20_avg_episodic_return=0.699999988079071
# local_step=471688, 20_avg_episodic_return=0.800000011920929
# local_step=473885, 20_avg_episodic_return=0.8500000238418579
# local_step=475705, 20_avg_episodic_return=0.949999988079071
# local_step=477607, 20_avg_episodic_return=0.6000000238418579
# local_step=479510, 20_avg_episodic_return=0.75
# local_step=481508, 20_avg_episodic_return=0.800000011920929
# local_step=482704, 20_avg_episodic_return=0.8999999761581421
# local_step=485332, 20_avg_episodic_return=0.800000011920929
# local_step=487112, 20_avg_episodic_return=0.800000011920929
# local_step=488373, 20_avg_episodic_return=0.75
# local_step=490700, 20_avg_episodic_return=0.8999999761581421
# local_step=492137, 20_avg_episodic_return=0.75
# local_step=493978, 20_avg_episodic_return=0.800000011920929
# local_step=495241, 20_avg_episodic_return=0.8500000238418579
# local_step=496862, 20_avg_episodic_return=0.800000011920929
# local_step=498524, 20_avg_episodic_return=0.8999999761581421
# local_step=500936, 20_avg_episodic_return=0.8500000238418579
# local_step=501944, 20_avg_episodic_return=0.8500000238418579
# local_step=503105, 20_avg_episodic_return=0.75
# local_step=504913, 20_avg_episodic_return=0.949999988079071
# local_step=505784, 20_avg_episodic_return=0.8500000238418579
# local_step=507505, 20_avg_episodic_return=0.8999999761581421
# local_step=509187, 20_avg_episodic_return=1.0
# local_step=510649, 20_avg_episodic_return=0.949999988079071
# local_step=512684, 20_avg_episodic_return=0.8999999761581421
# local_step=513935, 20_avg_episodic_return=0.8999999761581421
# local_step=515463, 20_avg_episodic_return=0.949999988079071
# local_step=517728, 20_avg_episodic_return=0.75
# local_step=519387, 20_avg_episodic_return=0.8500000238418579
# local_step=521247, 20_avg_episodic_return=0.8500000238418579
# local_step=522772, 20_avg_episodic_return=0.949999988079071
# local_step=524220, 20_avg_episodic_return=0.8500000238418579
# local_step=525236, 20_avg_episodic_return=1.0
# local_step=527001, 20_avg_episodic_return=0.8500000238418579
# local_step=528397, 20_avg_episodic_return=0.949999988079071
# local_step=529459, 20_avg_episodic_return=0.699999988079071
# local_step=530985, 20_avg_episodic_return=0.949999988079071
# local_step=532302, 20_avg_episodic_return=0.8999999761581421
# local_step=533854, 20_avg_episodic_return=0.8999999761581421
# local_step=535095, 20_avg_episodic_return=0.8999999761581421
# local_step=536511, 20_avg_episodic_return=1.0
# local_step=538045, 20_avg_episodic_return=0.8500000238418579
# local_step=539402, 20_avg_episodic_return=0.8500000238418579
# local_step=540926, 20_avg_episodic_return=0.8999999761581421
# local_step=542467, 20_avg_episodic_return=0.949999988079071
# local_step=544183, 20_avg_episodic_return=0.949999988079071
# local_step=545234, 20_avg_episodic_return=0.949999988079071
# local_step=546022, 20_avg_episodic_return=0.8500000238418579
# local_step=547422, 20_avg_episodic_return=1.0
# local_step=548556, 20_avg_episodic_return=1.0
# local_step=549861, 20_avg_episodic_return=0.949999988079071
# local_step=551248, 20_avg_episodic_return=0.949999988079071
# local_step=552479, 20_avg_episodic_return=0.949999988079071
# local_step=553713, 20_avg_episodic_return=0.949999988079071
# local_step=555255, 20_avg_episodic_return=0.8999999761581421
# local_step=556464, 20_avg_episodic_return=0.949999988079071
# local_step=557712, 20_avg_episodic_return=0.8999999761581421
# local_step=558995, 20_avg_episodic_return=1.0
# local_step=559989, 20_avg_episodic_return=0.8999999761581421
# local_step=561529, 20_avg_episodic_return=0.800000011920929
# local_step=562643, 20_avg_episodic_return=0.949999988079071
# local_step=563807, 20_avg_episodic_return=0.8999999761581421
# local_step=565331, 20_avg_episodic_return=0.8999999761581421
# local_step=566563, 20_avg_episodic_return=0.949999988079071
# local_step=567552, 20_avg_episodic_return=0.949999988079071
# local_step=568939, 20_avg_episodic_return=1.0
# local_step=569737, 20_avg_episodic_return=1.0
# local_step=571252, 20_avg_episodic_return=1.0
# local_step=572363, 20_avg_episodic_return=0.8500000238418579
# local_step=573745, 20_avg_episodic_return=0.8999999761581421
# local_step=575588, 20_avg_episodic_return=0.949999988079071
# local_step=577221, 20_avg_episodic_return=1.0
# local_step=578111, 20_avg_episodic_return=0.949999988079071
# local_step=579352, 20_avg_episodic_return=0.949999988079071
# local_step=580606, 20_avg_episodic_return=1.0
# local_step=581757, 20_avg_episodic_return=0.8999999761581421
# local_step=582796, 20_avg_episodic_return=0.949999988079071
# local_step=584042, 20_avg_episodic_return=0.949999988079071
# local_step=585505, 20_avg_episodic_return=0.949999988079071
# local_step=586497, 20_avg_episodic_return=0.8500000238418579
# local_step=587627, 20_avg_episodic_return=1.0
# local_step=588806, 20_avg_episodic_return=1.0
# local_step=590172, 20_avg_episodic_return=1.0
# local_step=591146, 20_avg_episodic_return=1.0
# local_step=592349, 20_avg_episodic_return=0.949999988079071
# local_step=593131, 20_avg_episodic_return=0.949999988079071
# local_step=593992, 20_avg_episodic_return=0.949999988079071
# local_step=594970, 20_avg_episodic_return=0.949999988079071
# local_step=596297, 20_avg_episodic_return=0.949999988079071
# local_step=597044, 20_avg_episodic_return=1.0
# local_step=598425, 20_avg_episodic_return=0.949999988079071
# local_step=599133, 20_avg_episodic_return=1.0
# local_step=600397, 20_avg_episodic_return=1.0
# local_step=601296, 20_avg_episodic_return=1.0
# local_step=602458, 20_avg_episodic_return=1.0
# local_step=603399, 20_avg_episodic_return=0.949999988079071
# local_step=604470, 20_avg_episodic_return=0.8999999761581421
# local_step=605504, 20_avg_episodic_return=1.0
# local_step=606645, 20_avg_episodic_return=0.8999999761581421
# local_step=607680, 20_avg_episodic_return=1.0
# local_step=608709, 20_avg_episodic_return=0.949999988079071
# local_step=609568, 20_avg_episodic_return=1.0
# local_step=610597, 20_avg_episodic_return=1.0
# local_step=611631, 20_avg_episodic_return=1.0
# local_step=612929, 20_avg_episodic_return=1.0
# local_step=613755, 20_avg_episodic_return=0.949999988079071
# local_step=614537, 20_avg_episodic_return=0.949999988079071
# local_step=615861, 20_avg_episodic_return=1.0
# local_step=616902, 20_avg_episodic_return=0.949999988079071
# local_step=617623, 20_avg_episodic_return=0.949999988079071
# local_step=618788, 20_avg_episodic_return=0.949999988079071
# local_step=619510, 20_avg_episodic_return=0.949999988079071
# local_step=620357, 20_avg_episodic_return=1.0
# local_step=621504, 20_avg_episodic_return=1.0
# local_step=622516, 20_avg_episodic_return=1.0
# local_step=623680, 20_avg_episodic_return=1.0
# local_step=624459, 20_avg_episodic_return=1.0
# local_step=625670, 20_avg_episodic_return=1.0
# local_step=626640, 20_avg_episodic_return=1.0
# local_step=627493, 20_avg_episodic_return=1.0
# local_step=628050, 20_avg_episodic_return=1.0
# local_step=629120, 20_avg_episodic_return=0.949999988079071
# local_step=629990, 20_avg_episodic_return=1.0
# local_step=630592, 20_avg_episodic_return=1.0
# local_step=631826, 20_avg_episodic_return=1.0
# local_step=632577, 20_avg_episodic_return=1.0
# local_step=633374, 20_avg_episodic_return=0.949999988079071
# local_step=634170, 20_avg_episodic_return=1.0
# local_step=634899, 20_avg_episodic_return=1.0
# local_step=636040, 20_avg_episodic_return=1.0
# local_step=636819, 20_avg_episodic_return=1.0
# local_step=637779, 20_avg_episodic_return=1.0
# local_step=638417, 20_avg_episodic_return=1.0
# local_step=639589, 20_avg_episodic_return=1.0
# local_step=640201, 20_avg_episodic_return=1.0
# local_step=641016, 20_avg_episodic_return=1.0
# local_step=642042, 20_avg_episodic_return=1.0
# local_step=642782, 20_avg_episodic_return=1.0
# local_step=643636, 20_avg_episodic_return=1.0
# local_step=644292, 20_avg_episodic_return=1.0
# local_step=644960, 20_avg_episodic_return=1.0
# local_step=645744, 20_avg_episodic_return=0.949999988079071
# local_step=646482, 20_avg_episodic_return=1.0
# local_step=647348, 20_avg_episodic_return=1.0
# local_step=648446, 20_avg_episodic_return=1.0
# local_step=649277, 20_avg_episodic_return=1.0
# local_step=650102, 20_avg_episodic_return=1.0
# local_step=650956, 20_avg_episodic_return=1.0
# local_step=651874, 20_avg_episodic_return=1.0
# local_step=652789, 20_avg_episodic_return=0.949999988079071
# local_step=653723, 20_avg_episodic_return=0.949999988079071
# local_step=654336, 20_avg_episodic_return=1.0
# local_step=655280, 20_avg_episodic_return=1.0
# local_step=656086, 20_avg_episodic_return=1.0
# local_step=656671, 20_avg_episodic_return=1.0
# local_step=657448, 20_avg_episodic_return=1.0
# local_step=658518, 20_avg_episodic_return=1.0
# local_step=659067, 20_avg_episodic_return=0.949999988079071
# local_step=659612, 20_avg_episodic_return=1.0
# local_step=660578, 20_avg_episodic_return=1.0
# local_step=661425, 20_avg_episodic_return=1.0
# local_step=662395, 20_avg_episodic_return=1.0
# local_step=663287, 20_avg_episodic_return=1.0
# local_step=664288, 20_avg_episodic_return=1.0
# local_step=665206, 20_avg_episodic_return=1.0
# local_step=665835, 20_avg_episodic_return=1.0
# local_step=666826, 20_avg_episodic_return=0.949999988079071
# local_step=667492, 20_avg_episodic_return=1.0
# local_step=668436, 20_avg_episodic_return=1.0
# local_step=669328, 20_avg_episodic_return=1.0
# local_step=670428, 20_avg_episodic_return=1.0
# local_step=671438, 20_avg_episodic_return=1.0
# local_step=672068, 20_avg_episodic_return=0.8999999761581421
# local_step=672932, 20_avg_episodic_return=1.0
# local_step=673903, 20_avg_episodic_return=1.0
# local_step=674403, 20_avg_episodic_return=1.0
# local_step=675407, 20_avg_episodic_return=1.0
# local_step=676053, 20_avg_episodic_return=1.0
# local_step=676672, 20_avg_episodic_return=1.0
# local_step=677422, 20_avg_episodic_return=1.0
# local_step=678426, 20_avg_episodic_return=0.949999988079071
# local_step=679319, 20_avg_episodic_return=1.0
# local_step=680401, 20_avg_episodic_return=1.0
# local_step=680967, 20_avg_episodic_return=1.0
# local_step=681998, 20_avg_episodic_return=0.949999988079071
# local_step=682607, 20_avg_episodic_return=1.0
# local_step=683282, 20_avg_episodic_return=1.0
# local_step=684018, 20_avg_episodic_return=1.0
# local_step=685213, 20_avg_episodic_return=1.0
# local_step=685756, 20_avg_episodic_return=1.0
# local_step=686677, 20_avg_episodic_return=1.0
# local_step=687225, 20_avg_episodic_return=0.949999988079071
# local_step=688297, 20_avg_episodic_return=1.0
# local_step=689041, 20_avg_episodic_return=1.0
# local_step=690114, 20_avg_episodic_return=1.0
# local_step=690901, 20_avg_episodic_return=1.0
# local_step=691450, 20_avg_episodic_return=1.0
# local_step=692130, 20_avg_episodic_return=1.0
# local_step=693030, 20_avg_episodic_return=1.0
# local_step=693824, 20_avg_episodic_return=0.949999988079071
# local_step=694971, 20_avg_episodic_return=1.0
# local_step=695540, 20_avg_episodic_return=1.0
# local_step=696063, 20_avg_episodic_return=1.0
# local_step=697095, 20_avg_episodic_return=0.949999988079071
# local_step=697934, 20_avg_episodic_return=1.0
# local_step=698612, 20_avg_episodic_return=1.0
# local_step=699694, 20_avg_episodic_return=0.949999988079071
# local_step=700397, 20_avg_episodic_return=1.0
# local_step=701256, 20_avg_episodic_return=1.0
# local_step=701959, 20_avg_episodic_return=0.949999988079071
# local_step=702805, 20_avg_episodic_return=1.0
# local_step=703563, 20_avg_episodic_return=1.0
# local_step=704113, 20_avg_episodic_return=0.949999988079071
# local_step=705054, 20_avg_episodic_return=1.0
# local_step=705622, 20_avg_episodic_return=1.0
# local_step=706511, 20_avg_episodic_return=0.949999988079071
# local_step=707344, 20_avg_episodic_return=1.0
# local_step=708407, 20_avg_episodic_return=1.0
# local_step=709517, 20_avg_episodic_return=1.0
# local_step=710474, 20_avg_episodic_return=1.0
# local_step=711261, 20_avg_episodic_return=1.0
# local_step=712281, 20_avg_episodic_return=0.949999988079071
# local_step=713267, 20_avg_episodic_return=1.0
# local_step=713987, 20_avg_episodic_return=1.0
# local_step=714679, 20_avg_episodic_return=1.0
# local_step=715454, 20_avg_episodic_return=1.0
# local_step=716510, 20_avg_episodic_return=1.0
# local_step=717451, 20_avg_episodic_return=1.0
# local_step=718130, 20_avg_episodic_return=1.0
# local_step=719060, 20_avg_episodic_return=1.0
# local_step=720155, 20_avg_episodic_return=1.0
# local_step=721071, 20_avg_episodic_return=0.949999988079071
# local_step=721888, 20_avg_episodic_return=1.0
# local_step=722500, 20_avg_episodic_return=0.949999988079071
# local_step=723081, 20_avg_episodic_return=1.0
# local_step=723645, 20_avg_episodic_return=1.0
# local_step=724691, 20_avg_episodic_return=1.0
# local_step=725351, 20_avg_episodic_return=1.0
# local_step=725898, 20_avg_episodic_return=1.0
# local_step=726998, 20_avg_episodic_return=1.0
# local_step=727809, 20_avg_episodic_return=0.949999988079071
# local_step=728294, 20_avg_episodic_return=1.0
# local_step=729148, 20_avg_episodic_return=0.949999988079071
# local_step=729900, 20_avg_episodic_return=1.0
# local_step=730582, 20_avg_episodic_return=1.0
# local_step=731191, 20_avg_episodic_return=1.0
# local_step=732126, 20_avg_episodic_return=1.0
# local_step=732632, 20_avg_episodic_return=1.0
# local_step=733250, 20_avg_episodic_return=1.0
# local_step=733783, 20_avg_episodic_return=1.0
# local_step=734755, 20_avg_episodic_return=1.0
# local_step=735510, 20_avg_episodic_return=1.0
# local_step=736196, 20_avg_episodic_return=1.0
# local_step=737314, 20_avg_episodic_return=1.0
# local_step=738171, 20_avg_episodic_return=1.0
# local_step=739009, 20_avg_episodic_return=1.0
# local_step=739647, 20_avg_episodic_return=0.8999999761581421
# local_step=740495, 20_avg_episodic_return=1.0
# local_step=741025, 20_avg_episodic_return=1.0
# local_step=741966, 20_avg_episodic_return=1.0
# local_step=742501, 20_avg_episodic_return=1.0
# local_step=743070, 20_avg_episodic_return=0.949999988079071
# local_step=743801, 20_avg_episodic_return=1.0
# local_step=744369, 20_avg_episodic_return=1.0
# local_step=745145, 20_avg_episodic_return=1.0
# local_step=745803, 20_avg_episodic_return=0.949999988079071
# local_step=746954, 20_avg_episodic_return=1.0
# local_step=747606, 20_avg_episodic_return=1.0
# local_step=748561, 20_avg_episodic_return=1.0
# local_step=749057, 20_avg_episodic_return=1.0
# local_step=749867, 20_avg_episodic_return=1.0
# local_step=750331, 20_avg_episodic_return=1.0
# local_step=750899, 20_avg_episodic_return=1.0
# local_step=751719, 20_avg_episodic_return=1.0
# local_step=752399, 20_avg_episodic_return=1.0
# local_step=752997, 20_avg_episodic_return=1.0
# local_step=753389, 20_avg_episodic_return=1.0
# local_step=754249, 20_avg_episodic_return=1.0
# local_step=754924, 20_avg_episodic_return=0.949999988079071
# local_step=755568, 20_avg_episodic_return=0.949999988079071
# local_step=756236, 20_avg_episodic_return=1.0
# local_step=756776, 20_avg_episodic_return=0.949999988079071
# local_step=757352, 20_avg_episodic_return=1.0
# local_step=757888, 20_avg_episodic_return=0.949999988079071
# local_step=758335, 20_avg_episodic_return=1.0
# local_step=759233, 20_avg_episodic_return=1.0
# local_step=759832, 20_avg_episodic_return=1.0
# local_step=760474, 20_avg_episodic_return=1.0
# local_step=760996, 20_avg_episodic_return=1.0
# local_step=761578, 20_avg_episodic_return=1.0
# local_step=762111, 20_avg_episodic_return=1.0
# local_step=762662, 20_avg_episodic_return=1.0
# local_step=763238, 20_avg_episodic_return=1.0
# local_step=763761, 20_avg_episodic_return=1.0
# local_step=764504, 20_avg_episodic_return=1.0
# local_step=765276, 20_avg_episodic_return=1.0
# local_step=765852, 20_avg_episodic_return=1.0
# local_step=766485, 20_avg_episodic_return=1.0
# local_step=767185, 20_avg_episodic_return=1.0
# local_step=767727, 20_avg_episodic_return=1.0
# local_step=768298, 20_avg_episodic_return=1.0
# local_step=768972, 20_avg_episodic_return=1.0
# local_step=769405, 20_avg_episodic_return=1.0
# local_step=770159, 20_avg_episodic_return=1.0
# local_step=770787, 20_avg_episodic_return=1.0
# local_step=771403, 20_avg_episodic_return=1.0
# local_step=772058, 20_avg_episodic_return=0.949999988079071
# local_step=772712, 20_avg_episodic_return=1.0
# local_step=773380, 20_avg_episodic_return=1.0
# local_step=774021, 20_avg_episodic_return=1.0
# local_step=774555, 20_avg_episodic_return=1.0
# local_step=775180, 20_avg_episodic_return=1.0
# local_step=775881, 20_avg_episodic_return=1.0
# local_step=776437, 20_avg_episodic_return=1.0
# local_step=777117, 20_avg_episodic_return=1.0
# local_step=777670, 20_avg_episodic_return=1.0
# local_step=778133, 20_avg_episodic_return=1.0
# local_step=778953, 20_avg_episodic_return=1.0
# local_step=779650, 20_avg_episodic_return=1.0
# local_step=780310, 20_avg_episodic_return=1.0
# local_step=780951, 20_avg_episodic_return=1.0
# local_step=781532, 20_avg_episodic_return=1.0
# local_step=782212, 20_avg_episodic_return=1.0
# local_step=782725, 20_avg_episodic_return=1.0
# local_step=783244, 20_avg_episodic_return=1.0
# local_step=783967, 20_avg_episodic_return=1.0
# local_step=784613, 20_avg_episodic_return=1.0
# local_step=785129, 20_avg_episodic_return=1.0
# local_step=785725, 20_avg_episodic_return=1.0
# local_step=786241, 20_avg_episodic_return=1.0
# local_step=786938, 20_avg_episodic_return=1.0
# local_step=787584, 20_avg_episodic_return=1.0
# local_step=788142, 20_avg_episodic_return=1.0
# local_step=788918, 20_avg_episodic_return=1.0
# local_step=789585, 20_avg_episodic_return=1.0
# local_step=790029, 20_avg_episodic_return=1.0
# local_step=790542, 20_avg_episodic_return=1.0
# local_step=791144, 20_avg_episodic_return=1.0
# local_step=791716, 20_avg_episodic_return=1.0
# local_step=792488, 20_avg_episodic_return=1.0
# local_step=793110, 20_avg_episodic_return=1.0
# local_step=793696, 20_avg_episodic_return=1.0
# local_step=794180, 20_avg_episodic_return=1.0
# local_step=794668, 20_avg_episodic_return=1.0
# local_step=795341, 20_avg_episodic_return=0.949999988079071
# local_step=796274, 20_avg_episodic_return=1.0
# local_step=796768, 20_avg_episodic_return=1.0
# local_step=797422, 20_avg_episodic_return=1.0
# local_step=797979, 20_avg_episodic_return=1.0
# local_step=798323, 20_avg_episodic_return=1.0
# local_step=799038, 20_avg_episodic_return=1.0
# local_step=799783, 20_avg_episodic_return=1.0
# local_step=800240, 20_avg_episodic_return=1.0
# local_step=800705, 20_avg_episodic_return=1.0
# local_step=801439, 20_avg_episodic_return=1.0
# local_step=802154, 20_avg_episodic_return=1.0
# local_step=802624, 20_avg_episodic_return=0.949999988079071
# local_step=803287, 20_avg_episodic_return=1.0
# local_step=803843, 20_avg_episodic_return=1.0
# local_step=804473, 20_avg_episodic_return=1.0
# local_step=805050, 20_avg_episodic_return=1.0
# local_step=805735, 20_avg_episodic_return=1.0
# local_step=806369, 20_avg_episodic_return=1.0
# local_step=806834, 20_avg_episodic_return=1.0
# local_step=807499, 20_avg_episodic_return=1.0
# local_step=808074, 20_avg_episodic_return=1.0
# local_step=808856, 20_avg_episodic_return=1.0
# local_step=809364, 20_avg_episodic_return=1.0
# local_step=809837, 20_avg_episodic_return=1.0
# local_step=810550, 20_avg_episodic_return=1.0
# local_step=811600, 20_avg_episodic_return=1.0
# local_step=812159, 20_avg_episodic_return=1.0
# local_step=812817, 20_avg_episodic_return=0.949999988079071
# local_step=813268, 20_avg_episodic_return=0.949999988079071
# local_step=813766, 20_avg_episodic_return=1.0
# local_step=814249, 20_avg_episodic_return=1.0
# local_step=814990, 20_avg_episodic_return=1.0
# local_step=815833, 20_avg_episodic_return=0.949999988079071
# local_step=816358, 20_avg_episodic_return=1.0
# local_step=816932, 20_avg_episodic_return=1.0
# local_step=817366, 20_avg_episodic_return=1.0
# local_step=817976, 20_avg_episodic_return=1.0
# local_step=818393, 20_avg_episodic_return=1.0
# local_step=818936, 20_avg_episodic_return=1.0
# local_step=819624, 20_avg_episodic_return=1.0
# local_step=820442, 20_avg_episodic_return=1.0
# local_step=821008, 20_avg_episodic_return=1.0
# local_step=821446, 20_avg_episodic_return=1.0
# local_step=822209, 20_avg_episodic_return=1.0
# local_step=822642, 20_avg_episodic_return=1.0
# local_step=823260, 20_avg_episodic_return=1.0
# local_step=823784, 20_avg_episodic_return=1.0
# local_step=824391, 20_avg_episodic_return=1.0
# local_step=824691, 20_avg_episodic_return=1.0
# local_step=825029, 20_avg_episodic_return=1.0
# local_step=825602, 20_avg_episodic_return=1.0
# local_step=826159, 20_avg_episodic_return=1.0
# local_step=827051, 20_avg_episodic_return=1.0
# local_step=827705, 20_avg_episodic_return=1.0
# local_step=828134, 20_avg_episodic_return=1.0
# local_step=828677, 20_avg_episodic_return=1.0
# local_step=829401, 20_avg_episodic_return=1.0
# local_step=829869, 20_avg_episodic_return=1.0
# local_step=830312, 20_avg_episodic_return=1.0
# local_step=830947, 20_avg_episodic_return=1.0
# local_step=831448, 20_avg_episodic_return=1.0
# local_step=831860, 20_avg_episodic_return=1.0
# local_step=832505, 20_avg_episodic_return=1.0
# local_step=833216, 20_avg_episodic_return=1.0
# local_step=833563, 20_avg_episodic_return=1.0
# local_step=834081, 20_avg_episodic_return=1.0
# local_step=834627, 20_avg_episodic_return=1.0
# local_step=835317, 20_avg_episodic_return=1.0
# local_step=835985, 20_avg_episodic_return=1.0
# local_step=836570, 20_avg_episodic_return=1.0
# local_step=837030, 20_avg_episodic_return=1.0
# local_step=837428, 20_avg_episodic_return=1.0
# local_step=837832, 20_avg_episodic_return=1.0
# local_step=838621, 20_avg_episodic_return=1.0
# local_step=839267, 20_avg_episodic_return=1.0
# local_step=839831, 20_avg_episodic_return=1.0
# local_step=840272, 20_avg_episodic_return=1.0
# local_step=840732, 20_avg_episodic_return=1.0
# local_step=841613, 20_avg_episodic_return=1.0
# local_step=842153, 20_avg_episodic_return=1.0
# local_step=842590, 20_avg_episodic_return=1.0
# local_step=843258, 20_avg_episodic_return=0.949999988079071
# local_step=843812, 20_avg_episodic_return=1.0
# local_step=844423, 20_avg_episodic_return=1.0
# local_step=845029, 20_avg_episodic_return=1.0
# local_step=845414, 20_avg_episodic_return=1.0
# local_step=846071, 20_avg_episodic_return=1.0
# local_step=846426, 20_avg_episodic_return=1.0
# local_step=847129, 20_avg_episodic_return=1.0
# local_step=847596, 20_avg_episodic_return=1.0
# local_step=848464, 20_avg_episodic_return=1.0
# local_step=849052, 20_avg_episodic_return=1.0
# local_step=849785, 20_avg_episodic_return=1.0
# local_step=850357, 20_avg_episodic_return=1.0
# local_step=850883, 20_avg_episodic_return=1.0
# local_step=851629, 20_avg_episodic_return=1.0
# local_step=852188, 20_avg_episodic_return=1.0
# local_step=852601, 20_avg_episodic_return=1.0
# local_step=853043, 20_avg_episodic_return=1.0
# local_step=853880, 20_avg_episodic_return=1.0
# local_step=854391, 20_avg_episodic_return=1.0
# local_step=854905, 20_avg_episodic_return=1.0
# local_step=855324, 20_avg_episodic_return=1.0
# local_step=855913, 20_avg_episodic_return=1.0
# local_step=856340, 20_avg_episodic_return=1.0
# local_step=856934, 20_avg_episodic_return=1.0
# local_step=857486, 20_avg_episodic_return=1.0
# local_step=857977, 20_avg_episodic_return=1.0
# local_step=858607, 20_avg_episodic_return=1.0
# local_step=859148, 20_avg_episodic_return=1.0
# local_step=859677, 20_avg_episodic_return=1.0
# local_step=860010, 20_avg_episodic_return=1.0
# local_step=860592, 20_avg_episodic_return=1.0
# local_step=861348, 20_avg_episodic_return=1.0
# local_step=861869, 20_avg_episodic_return=1.0
# local_step=862338, 20_avg_episodic_return=1.0
# local_step=862982, 20_avg_episodic_return=1.0
# local_step=863524, 20_avg_episodic_return=1.0
# local_step=864000, 20_avg_episodic_return=1.0
# local_step=864549, 20_avg_episodic_return=1.0
# local_step=864954, 20_avg_episodic_return=1.0
# local_step=865495, 20_avg_episodic_return=0.949999988079071
# local_step=866170, 20_avg_episodic_return=1.0
# local_step=866722, 20_avg_episodic_return=1.0
# local_step=867090, 20_avg_episodic_return=1.0
# local_step=867735, 20_avg_episodic_return=1.0
# local_step=868559, 20_avg_episodic_return=1.0
# local_step=869026, 20_avg_episodic_return=1.0
# local_step=869459, 20_avg_episodic_return=1.0
# local_step=870048, 20_avg_episodic_return=1.0
# local_step=870632, 20_avg_episodic_return=1.0
# local_step=871242, 20_avg_episodic_return=1.0
# local_step=871779, 20_avg_episodic_return=1.0
# local_step=872348, 20_avg_episodic_return=1.0
# local_step=872930, 20_avg_episodic_return=1.0
# local_step=873640, 20_avg_episodic_return=1.0
# local_step=874064, 20_avg_episodic_return=1.0
# local_step=874610, 20_avg_episodic_return=1.0
# local_step=875033, 20_avg_episodic_return=1.0
# local_step=875424, 20_avg_episodic_return=1.0
# local_step=876091, 20_avg_episodic_return=1.0
# local_step=876531, 20_avg_episodic_return=1.0
# local_step=876985, 20_avg_episodic_return=1.0
# local_step=877490, 20_avg_episodic_return=1.0
# local_step=878253, 20_avg_episodic_return=1.0
# local_step=878761, 20_avg_episodic_return=1.0
# local_step=879264, 20_avg_episodic_return=1.0
# local_step=879639, 20_avg_episodic_return=1.0
# local_step=880227, 20_avg_episodic_return=1.0
# local_step=880743, 20_avg_episodic_return=1.0
# local_step=881322, 20_avg_episodic_return=1.0
# local_step=881751, 20_avg_episodic_return=1.0
# local_step=882362, 20_avg_episodic_return=1.0
# local_step=882972, 20_avg_episodic_return=1.0
# local_step=883442, 20_avg_episodic_return=0.949999988079071
# local_step=883865, 20_avg_episodic_return=1.0
# local_step=884415, 20_avg_episodic_return=1.0
# local_step=885111, 20_avg_episodic_return=1.0
# local_step=885546, 20_avg_episodic_return=1.0
# local_step=885980, 20_avg_episodic_return=1.0
# local_step=886477, 20_avg_episodic_return=1.0
# local_step=886886, 20_avg_episodic_return=1.0
# local_step=887322, 20_avg_episodic_return=1.0
# local_step=887831, 20_avg_episodic_return=1.0
# local_step=888521, 20_avg_episodic_return=1.0
# local_step=889112, 20_avg_episodic_return=0.949999988079071
# local_step=889674, 20_avg_episodic_return=1.0
# local_step=890234, 20_avg_episodic_return=1.0
# local_step=890767, 20_avg_episodic_return=1.0
# local_step=891291, 20_avg_episodic_return=1.0
# local_step=891676, 20_avg_episodic_return=1.0
# local_step=892148, 20_avg_episodic_return=1.0
# local_step=892857, 20_avg_episodic_return=1.0
# local_step=893332, 20_avg_episodic_return=1.0
# local_step=893664, 20_avg_episodic_return=1.0
# local_step=894424, 20_avg_episodic_return=0.949999988079071
# local_step=894819, 20_avg_episodic_return=1.0
# local_step=895440, 20_avg_episodic_return=1.0
# local_step=895858, 20_avg_episodic_return=1.0
# local_step=896319, 20_avg_episodic_return=1.0
# local_step=896716, 20_avg_episodic_return=1.0
# local_step=897331, 20_avg_episodic_return=1.0
# local_step=897722, 20_avg_episodic_return=1.0
# local_step=898267, 20_avg_episodic_return=1.0
# local_step=898854, 20_avg_episodic_return=1.0
# local_step=899247, 20_avg_episodic_return=1.0
# local_step=899722, 20_avg_episodic_return=1.0
# local_step=900178, 20_avg_episodic_return=1.0
# local_step=900679, 20_avg_episodic_return=1.0
# local_step=901289, 20_avg_episodic_return=1.0
# local_step=901631, 20_avg_episodic_return=1.0
# local_step=902164, 20_avg_episodic_return=1.0
# local_step=902826, 20_avg_episodic_return=1.0
# local_step=903266, 20_avg_episodic_return=1.0
# local_step=903682, 20_avg_episodic_return=1.0
# local_step=904232, 20_avg_episodic_return=1.0
# local_step=904822, 20_avg_episodic_return=1.0
# local_step=905134, 20_avg_episodic_return=1.0
# local_step=905768, 20_avg_episodic_return=1.0
# local_step=906328, 20_avg_episodic_return=1.0
# local_step=906819, 20_avg_episodic_return=1.0
# local_step=907295, 20_avg_episodic_return=1.0
# local_step=907810, 20_avg_episodic_return=1.0
# local_step=908423, 20_avg_episodic_return=1.0
# local_step=909084, 20_avg_episodic_return=1.0
# local_step=909590, 20_avg_episodic_return=1.0
# local_step=910046, 20_avg_episodic_return=1.0
# local_step=910587, 20_avg_episodic_return=1.0
# local_step=911079, 20_avg_episodic_return=1.0
# local_step=911660, 20_avg_episodic_return=1.0
# local_step=912055, 20_avg_episodic_return=1.0
# local_step=912909, 20_avg_episodic_return=1.0
# local_step=913356, 20_avg_episodic_return=1.0
# local_step=913941, 20_avg_episodic_return=1.0
# local_step=914425, 20_avg_episodic_return=1.0
# local_step=914947, 20_avg_episodic_return=1.0
# local_step=915580, 20_avg_episodic_return=1.0
# local_step=916155, 20_avg_episodic_return=1.0
# local_step=916749, 20_avg_episodic_return=1.0
# local_step=917285, 20_avg_episodic_return=1.0
# local_step=917902, 20_avg_episodic_return=1.0
# local_step=918362, 20_avg_episodic_return=1.0
# local_step=918804, 20_avg_episodic_return=1.0
# local_step=919369, 20_avg_episodic_return=1.0
# local_step=919775, 20_avg_episodic_return=1.0
# local_step=920162, 20_avg_episodic_return=1.0
# local_step=920798, 20_avg_episodic_return=1.0
# local_step=921331, 20_avg_episodic_return=1.0
# local_step=921722, 20_avg_episodic_return=1.0
# local_step=922392, 20_avg_episodic_return=1.0
# local_step=922893, 20_avg_episodic_return=1.0
# local_step=923381, 20_avg_episodic_return=0.949999988079071
# local_step=923918, 20_avg_episodic_return=1.0
# local_step=924427, 20_avg_episodic_return=1.0
# local_step=924850, 20_avg_episodic_return=1.0
# local_step=925404, 20_avg_episodic_return=1.0
# local_step=925877, 20_avg_episodic_return=1.0
# local_step=926379, 20_avg_episodic_return=1.0
# local_step=926995, 20_avg_episodic_return=1.0
# local_step=927458, 20_avg_episodic_return=1.0
# local_step=928097, 20_avg_episodic_return=0.949999988079071
# local_step=928415, 20_avg_episodic_return=1.0
# local_step=928937, 20_avg_episodic_return=1.0
# local_step=929371, 20_avg_episodic_return=1.0
# local_step=929804, 20_avg_episodic_return=1.0
# local_step=930532, 20_avg_episodic_return=1.0
# local_step=931153, 20_avg_episodic_return=1.0
# local_step=931668, 20_avg_episodic_return=1.0
# local_step=931991, 20_avg_episodic_return=1.0
# local_step=932536, 20_avg_episodic_return=1.0
# local_step=932877, 20_avg_episodic_return=1.0
# local_step=933487, 20_avg_episodic_return=1.0
# local_step=933781, 20_avg_episodic_return=1.0
# local_step=934335, 20_avg_episodic_return=1.0
# local_step=934687, 20_avg_episodic_return=1.0
# local_step=935241, 20_avg_episodic_return=1.0
# local_step=935726, 20_avg_episodic_return=1.0
# local_step=936499, 20_avg_episodic_return=1.0
# local_step=936986, 20_avg_episodic_return=1.0
# local_step=937399, 20_avg_episodic_return=1.0
# local_step=937961, 20_avg_episodic_return=1.0
# local_step=938501, 20_avg_episodic_return=1.0
# local_step=938883, 20_avg_episodic_return=0.949999988079071
# local_step=939436, 20_avg_episodic_return=1.0
# local_step=939977, 20_avg_episodic_return=1.0
# local_step=940550, 20_avg_episodic_return=1.0
# local_step=940957, 20_avg_episodic_return=1.0
# local_step=941463, 20_avg_episodic_return=1.0
# local_step=941911, 20_avg_episodic_return=0.949999988079071
# local_step=942477, 20_avg_episodic_return=1.0
# local_step=942924, 20_avg_episodic_return=1.0
# local_step=943639, 20_avg_episodic_return=1.0
# local_step=944273, 20_avg_episodic_return=1.0
# local_step=944544, 20_avg_episodic_return=1.0
# local_step=945119, 20_avg_episodic_return=1.0
# local_step=945626, 20_avg_episodic_return=1.0
# local_step=946034, 20_avg_episodic_return=1.0
# local_step=946816, 20_avg_episodic_return=1.0
# local_step=947261, 20_avg_episodic_return=1.0
# local_step=947693, 20_avg_episodic_return=1.0
# local_step=948308, 20_avg_episodic_return=1.0
# local_step=948797, 20_avg_episodic_return=1.0
# local_step=949431, 20_avg_episodic_return=1.0
# local_step=949795, 20_avg_episodic_return=1.0
# local_step=950379, 20_avg_episodic_return=1.0
# local_step=950837, 20_avg_episodic_return=1.0
# local_step=951223, 20_avg_episodic_return=1.0
# local_step=951757, 20_avg_episodic_return=1.0
# local_step=952408, 20_avg_episodic_return=1.0
# local_step=952788, 20_avg_episodic_return=1.0
# local_step=953259, 20_avg_episodic_return=1.0
# local_step=953894, 20_avg_episodic_return=1.0
# local_step=954332, 20_avg_episodic_return=1.0
# local_step=954791, 20_avg_episodic_return=1.0
# local_step=955291, 20_avg_episodic_return=1.0
# local_step=955864, 20_avg_episodic_return=1.0
# local_step=956226, 20_avg_episodic_return=1.0
# local_step=956815, 20_avg_episodic_return=1.0
# local_step=957522, 20_avg_episodic_return=1.0
# local_step=957894, 20_avg_episodic_return=1.0
# local_step=958370, 20_avg_episodic_return=1.0
# local_step=958883, 20_avg_episodic_return=1.0
# local_step=959356, 20_avg_episodic_return=1.0
# local_step=959883, 20_avg_episodic_return=1.0
# local_step=960222, 20_avg_episodic_return=0.949999988079071
# local_step=960728, 20_avg_episodic_return=1.0
# local_step=961488, 20_avg_episodic_return=1.0
# local_step=961988, 20_avg_episodic_return=1.0
# local_step=962420, 20_avg_episodic_return=1.0
# local_step=962887, 20_avg_episodic_return=1.0
# local_step=963385, 20_avg_episodic_return=1.0
# local_step=963797, 20_avg_episodic_return=1.0
# local_step=964345, 20_avg_episodic_return=1.0
# local_step=964769, 20_avg_episodic_return=1.0
# local_step=965609, 20_avg_episodic_return=1.0
# local_step=965967, 20_avg_episodic_return=1.0
# local_step=966378, 20_avg_episodic_return=1.0
# local_step=966844, 20_avg_episodic_return=1.0
# local_step=967324, 20_avg_episodic_return=1.0
# local_step=967862, 20_avg_episodic_return=1.0
# local_step=968532, 20_avg_episodic_return=1.0
# local_step=968953, 20_avg_episodic_return=1.0
# local_step=969425, 20_avg_episodic_return=1.0
# local_step=969775, 20_avg_episodic_return=1.0
# local_step=970371, 20_avg_episodic_return=1.0
# local_step=970860, 20_avg_episodic_return=1.0
# local_step=971475, 20_avg_episodic_return=1.0
# local_step=971934, 20_avg_episodic_return=1.0
# local_step=972432, 20_avg_episodic_return=1.0
# local_step=972884, 20_avg_episodic_return=1.0
# local_step=973321, 20_avg_episodic_return=1.0
# local_step=973928, 20_avg_episodic_return=1.0
# local_step=974463, 20_avg_episodic_return=1.0
# local_step=975027, 20_avg_episodic_return=1.0
# local_step=975388, 20_avg_episodic_return=1.0
# local_step=975876, 20_avg_episodic_return=1.0
# local_step=976362, 20_avg_episodic_return=1.0
# local_step=976809, 20_avg_episodic_return=1.0
# local_step=977171, 20_avg_episodic_return=1.0
# local_step=977746, 20_avg_episodic_return=1.0
# local_step=978228, 20_avg_episodic_return=1.0
# local_step=978664, 20_avg_episodic_return=1.0
# local_step=979282, 20_avg_episodic_return=0.949999988079071
# local_step=979775, 20_avg_episodic_return=1.0
# local_step=980192, 20_avg_episodic_return=1.0
# local_step=980595, 20_avg_episodic_return=0.949999988079071
# local_step=981055, 20_avg_episodic_return=1.0
# local_step=981770, 20_avg_episodic_return=1.0
# local_step=982244, 20_avg_episodic_return=1.0
# local_step=982800, 20_avg_episodic_return=1.0
# local_step=983224, 20_avg_episodic_return=1.0
# local_step=983755, 20_avg_episodic_return=1.0
# local_step=984329, 20_avg_episodic_return=1.0
# local_step=984679, 20_avg_episodic_return=1.0
# local_step=985248, 20_avg_episodic_return=0.949999988079071
# local_step=985660, 20_avg_episodic_return=1.0
# local_step=986092, 20_avg_episodic_return=1.0
# local_step=986617, 20_avg_episodic_return=1.0
# local_step=987109, 20_avg_episodic_return=1.0
# local_step=987480, 20_avg_episodic_return=1.0
# local_step=987854, 20_avg_episodic_return=1.0
# local_step=988309, 20_avg_episodic_return=1.0
# local_step=988872, 20_avg_episodic_return=1.0
# local_step=989423, 20_avg_episodic_return=1.0
# local_step=989938, 20_avg_episodic_return=1.0
# local_step=990609, 20_avg_episodic_return=1.0
# local_step=991005, 20_avg_episodic_return=1.0
# local_step=991547, 20_avg_episodic_return=1.0
# local_step=992125, 20_avg_episodic_return=1.0
# local_step=992535, 20_avg_episodic_return=1.0
# local_step=992968, 20_avg_episodic_return=1.0
# local_step=993430, 20_avg_episodic_return=1.0
# local_step=993781, 20_avg_episodic_return=1.0
# local_step=994316, 20_avg_episodic_return=1.0
# local_step=994944, 20_avg_episodic_return=1.0
# local_step=995358, 20_avg_episodic_return=1.0
# local_step=995859, 20_avg_episodic_return=1.0
# local_step=996285, 20_avg_episodic_return=1.0
# local_step=996975, 20_avg_episodic_return=1.0
# local_step=997599, 20_avg_episodic_return=1.0
# local_step=997885, 20_avg_episodic_return=1.0
# local_step=998484, 20_avg_episodic_return=1.0
# local_step=998865, 20_avg_episodic_return=1.0
# /home/maciej/anaconda3/envs/rl/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning:
#
# WARN: env.gym_env to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.gym_env` for environment variables or `env.get_wrapper_attr('gym_env')` that will search the reminding wrappers.
#
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 430) to (608, 432) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# reward: 1.0, steps: 17
# [swscaler @ 0x6144640] Warning: data is not aligned! This can lead to a speed loss
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### PPO should be able to solve this environment in 1M env steps

# %% [markdown]
# # Task 2: Random Network Distillation

# %% [markdown]
# ## Motivation behind Random Network Distillation
#
# Exploitation versus exploration is a critical topic in Reinforcement Learning. We'd like the RL agent to find the best solution as fast as possible. However, in the meantime, committing to solutions too quickly without enough exploration sounds pretty bad, as it could lead to local minima or total failure. Modern RL algorithms that optimize for the best returns can achieve good exploitation quite efficiently, while exploration remains more like an open topic.
#
# ### Classic exploration strategies
#
# As a quick recap, let's first go through several classic exploration algorithms.
# - Epsilon-greedy: The agent does random exploration occasionally with probability and takes the optimal action most of the time with probability ($1 - \epsilon$).
# - Entropy loss term: Add an entropy term $H(\pi(a|s))$ into the loss function, encouraging the policy to take diverse actions.
#
# ### The Hard Exploration problem
#
# The “hard-exploration” problem refers to exploration in an environment with very sparse or even deceptive rewards. It is difficult because random exploration in such scenarios can rarely discover successful states or obtain meaningful feedback.
#
# [Montezuma's Revenge](https://en.wikipedia.org/wiki/Montezuma%27s_Revenge_(video_game)) is a concrete example of the hard-exploration problem. It is one of a few challenging games in Atari for DRL to solve. Many papers use Montezuma's Revenge to benchmark their results.
#
# ### Intrinsic Rewards as Exploration Bonuses
# One common approach to better exploration, especially for solving the hard-exploration problem, is to augment the environment reward with an additional bonus signal to encourage extra exploration. The policy is thus trained with a reward composed of two terms $r_t = r_t^e + \beta r_t^i$, where $\beta$ is a hyperparameter adjusting the balance between exploitation and exploration.
#
# - $r_t^e$ is an extrinsic reward from the environment at time $t$, defined according to the task in hand.
# - $r_t^i$ is an intrinsic exploration bonus at time $t$.
#
# This intrinsic reward is somewhat inspired by intrinsic motivation in psychology (Oudeyer & Kaplan, 2008). Exploration driven by curiosity might be an important way for children to grow and learn. In other words, exploratory activities should be rewarding intrinsically in the human mind to encourage such behavior. The intrinsic rewards could be correlated with curiosity, surprise, familiarity with the state, and many other factors.
#
# ### Prediction based exploration
# In this homework, we will focus on intrinsic exploration bonuses rewarded for the improvement of the agent's knowledge about the environment. The agent's familiarity with the environment dynamics can be estimated through a prediction model. This idea of using a prediction model to measure curiosity was actually proposed quite a long time ago (Schmidhuber, 1991).
#
# Specifically, we will implement Random Network Distillation (RND; Burda, et al. 2018) which introduces a prediction task <i>independent</i> of the main task. The RND exploration bonus is defined as the error of a neural network $\hat{f}(s_t)$ predicting features of the observations given by a <i>fixed randomly initialized</i> neural network $f(s_t)$. The motivation is that given a new state, if similar states have been visited many times in the past, the prediction should be easier and thus have lower error. The exploration bonus is
# $r_i = |\hat{f}(s_t; \theta) - f(s_t)|_2^2$
#
# ![img](https://drive.google.com/uc?export=view&id=1WB_T4kHtaE-oJWR-NedX0Mw-I1It4F31)
#
# Two factors are important in RND experiments:
#
# 1. Non-episodic setting results in better exploration, especially when not using any extrinsic rewards. It means that the return is not truncated at “Game over” and intrinsic return can spread across multiple episodes.
# 2. Normalization is important since the scale of the reward is tricky to adjust given a random neural network as a prediction target. The intrinsic reward is normalized by division by a running estimate of the standard deviations of the intrinsic return.
#
# The RND setup works well for resolving the hard-exploration problem. For example, maximizing the RND exploration bonus consistently finds more than half of the rooms in Montezuma's Revenge.

# %% [markdown]
# ## Implement RND model class
#
# For this task, you need to implement a Random Network Distillation (RND) model, the backbone of curiosity-driven exploration. The model consists of two main components - `target` and `predictor` that <b>should not have shared components</b>! You can use a similar approach for encoding observation as in the Agent. The predictor network is trainable and tries to predict the outputs of the target network, which remains fixed (non-trainable).

# %%
class RNDModel(nn.Module):
    def __init__(self, env):
        super().__init__()

        self.dtype = pufferlib.pytorch.nativize_dtype(env.emulated)

        # Predictor Network
        self.predictor_blstats_net = nn.Sequential(
            nn.Embedding(256, 32),
            nn.Flatten(),
        )

        self.predictor_char_embed = nn.Embedding(256, 32)
        self.predictor_chars_net = nn.Sequential(
            layer_init(nn.Conv2d(32, 32, 5, stride=(2, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 5, stride=(1, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
        )

        self.predictor_proj = nn.Linear(864+960, 256)
        self.predictor = nn.Sequential(
            layer_init(nn.Linear(256, 512)),
            nn.ReLU(),
            layer_init(nn.Linear(512, 512)),
            nn.ReLU(),
            layer_init(nn.Linear(512, 512)),
        )

        # Target Network
        self.target_blstats_net = nn.Sequential(
            nn.Embedding(256, 32),
            nn.Flatten(),
        )

        self.target_char_embed = nn.Embedding(256, 32)
        self.target_chars_net = nn.Sequential(
            layer_init(nn.Conv2d(32, 32, 5, stride=(2, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(32, 64, 5, stride=(1, 3))),
            nn.ReLU(),
            layer_init(nn.Conv2d(64, 64, 3, stride=1)),
            nn.ReLU(),
            nn.Flatten(),
        )

        self.target_proj = nn.Linear(864+960, 256)
        self.target = nn.Sequential(
            layer_init(nn.Linear(256, 512)),
        )

        # target network is not trainable
        for name, param in self.named_parameters():
            if name.startswith('target'):
                param.requires_grad = False

    def encode_predictor(self, x):
        x = x.type(torch.uint8)  # Undo bad cleanrl cast
        x = pufferlib.pytorch.nativize_tensor(x, self.dtype)

        blstats = torch.clip(x['blstats'] + 1, 0, 255).int()
        blstats = self.predictor_blstats_net(blstats)

        chars = self.predictor_char_embed(x['chars'].int())
        chars = torch.permute(chars, (0, 3, 1, 2))
        chars = self.predictor_chars_net(chars)

        concat = torch.cat([blstats, chars], dim=1)
        return self.predictor_proj(concat)

    def encode_target(self, x):
        x = x.type(torch.uint8)  # Undo bad cleanrl cast
        x = pufferlib.pytorch.nativize_tensor(x, self.dtype)

        blstats = torch.clip(x['blstats'] + 1, 0, 255).int()
        blstats = self.target_blstats_net(blstats)

        chars = self.target_char_embed(x['chars'].int())
        chars = torch.permute(chars, (0, 3, 1, 2))
        chars = self.target_chars_net(chars)

        concat = torch.cat([blstats, chars], dim=1)
        return self.target_proj(concat)

    def forward(self, next_obs):
        """
        Encode observations with `encode_predictor` and `encode_target`.
        Infer `predictor` and `target` networks to return their predictions.
        """
        ### BEGIN SOLUTION - RND forward

        ### END SOLUTION
        return predict_feature, target_feature

# %% [markdown]
# ## RND Trainer

# %%
class RNDTrainer(PPOTrainer):
    def __init__(self, args, writer, env, agent, rnd_model, tlol):
        super().__init__(args, writer, env, agent, tlol)
        self.rnd_model = rnd_model
        self.curiosity_rewards = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)
        self.int_values = torch.zeros((self.args.num_steps, self.args.num_envs)).to(self.device)

        self.combined_parameters = list(self.agent.parameters()) + list(self.rnd_model.predictor.parameters())
        self.optimizer = optim.Adam(
            self.combined_parameters,
            lr=self.args.learning_rate,
            eps=1e-5,
        )

    def calculate_curiosity_rewards(self, step, next_obs):
        """
        Your task is to implement the computation of curiosity-driven rewards.
        Curiosity rewards are used to encourage the agent to explore novel states by quantifying the prediction error
        of a Random Network Distillation (RND) model. The larger the prediction error, the more novel the state is
        considered, and the higher the reward.

        Available Variables:
        - `self.obs_rms.mean` (np.Array): The running mean of observations.
        - `self.obs_rms.var` (np.Array): The running variance of observations.
        - `self.rnd_model(obs)`: A method that takes an observation as input and returns two outputs:
            1. `predict_next_feature`: The output of the predictor network.
            2. `target_next_feature`: The output of the fixed target network.
        - `self.curiosity_rewards`: A tensor where curiosity rewards for each timestep are stored.

        Implementation Details:
        - Normalize `next_obs` using running mean (`self.obs_rms.mean`) and variance (`self.obs_rms.var`).
        Clip normalized values to a range of [-5, 5] for numerical stability.
        - Pass the normalized observation (`rnd_next_obs`) through the RND model to obtain `predict_next_feature`
        and `target_next_feature`.
        - Compute curiosity reward as half of the squared L2 norm of the difference between
        `target_next_feature` and `predict_next_feature`.
        - Store the computed reward in `self.curiosity_rewards[step]` as a tensor on the `self.device`.
        - Other components of the `steps_curiosity_rewards` have to be casted to tensors and put on the `self.device` 
        """
        ### BEGIN SOLUTION - RNDT calculate_curiosity_rewards

        ### END SOLUTION
        self.curiosity_rewards[step] = steps_curiosity_rewards


    def compute_int_advantages(self, next_obs):
        """
        Your task is to implement the computation of advantages specifically for intrinsic rewards using Generalized Advantage Estimation (GAE).
        This method is similar to `compute_advantages`, which you have already seen, but it focuses on intrinsic rewards instead of extrinsic rewards.

        Available Variables:
        - `self.curiosity_rewards`: A tensor containing intrinsic rewards for each timestep in the trajectory.
        - `self.int_values`: A tensor containing value estimates for intrinsic rewards at each timestep.
        - `self.agent.get_value(obs)`: A method that returns value estimates; the second output corresponds to intrinsic values.
        - `self.args.int_gamma`: The discount factor for intrinsic rewards.
        - `self.args.gae_lambda`: The GAE lambda parameter.

        Notes: 
        - Intrinsic rewards do not depend on terminal states
        - Solution will be very similar to `PPOTrainer.compute_advantages` with variables from the `self.RNDTrainer` 
        """


        with torch.no_grad():
            ### BEGIN SOLUTION - RNDT compute_int_advantages

            ### END SOLUTION
        return int_advantages

    def compute_rnd_loss(self, rnd_next_obs):
        """
        Your task is to implement the computation of the RND loss.

        Available Variables and Methods:
        - `self.rnd_model(obs)`: A method that takes an observation as input and returns two outputs:
            1. `predict_next_state_feature`: The output of the predictor network.
            2. `target_next_state_feature`: The output of the fixed target network.
        - `F.mse_loss`: A PyTorch function to compute mean squared error.
        - `self.args.update_proportion`: A float value indicating the proportion of samples to use for updating.
        - `self.device`: The device (CPU or GPU) on which computations are performed.

        Implementation Details:
        - Compute the forward loss as the mean squared error between `predict_next_state_feature` and `target_next_state_feature`.
        Ensure that gradients are not computed for the target network by detaching it.
        - Create a random mask to select a subset of samples based on `self.args.update_proportion`.
        Use this mask to filter which samples contribute to the loss.
        - Normalize the loss by dividing by the sum of masked elements, ensuring numerical stability by handling cases where
        no elements are selected.
        """

        ### BEGIN SOLUTION - RNDT compute_rnd_loss

        ### END SOLUTION
        return forward_loss

    def train(self):
        # ALGO Logic: Storage setup
        avg_returns = deque(maxlen=self.av_er_interval)
        avg_curiosity_reward = deque(maxlen=self.av_er_interval)

        # start the game
        global_step = 0
        start_time = time.time()
        next_obs = torch.Tensor(self.env.reset()[0]).to(self.device)
        next_done = torch.zeros(self.args.num_envs).to(self.device)
        next_time_out = torch.zeros(self.args.num_envs).to(self.device)
        num_updates = self.args.total_timesteps // self.args.batch_size

        reward_rms = RunningMeanStd()
        self.obs_rms = RunningMeanStd(shape=(1,) + self.env.single_observation_space.shape)
        discounted_reward = RewardForwardFilter(self.args.int_gamma)

        print("Start to initialize observation normalization parameter.....")
        next_ob = []
        for step in range(self.args.num_steps * self.args.num_iterations_obs_norm_init):
            acs = np.random.randint(0, self.env.single_action_space.n, size=(self.args.num_envs,))
            o, r, te, tr, _ = self.env.step(acs)
            next_ob += o.tolist()

            if len(next_ob) % (self.args.num_steps * self.args.num_envs) == 0:
                next_ob = np.stack(next_ob)
                self.obs_rms.update(next_ob)
                next_ob = []
        print("End to initialize...")

        for update in range(1, num_updates + 1):
            # Annealing the rate if instructed to do so.
            if self.args.anneal_lr:
                frac = 1.0 - (update - 1.0) / num_updates
                lrnow = frac * self.args.learning_rate
                self.optimizer.param_groups[0]["lr"] = lrnow

            for step in range(0, self.args.num_steps):
                global_step += 1 * self.args.num_envs
                self.obs[step] = next_obs
                self.dones[step] = next_done
                self.time_outs[step] = next_time_out

                # ALGO LOGIC: action logic
                with torch.no_grad():
                    value_ext, value_int = self.agent.get_value(self.obs[step])
                    self.ext_values[step], self.int_values[step] = (
                        value_ext.flatten(),
                        value_int.flatten(),
                    )
                    action, logprob, _, _, _ = self.agent.get_action_and_value(self.obs[step])

                self.actions[step] = action
                self.logprobs[step] = logprob

                # execute the game and log data.
                next_obs, reward, terminated, truncated, info = self.env.step(action.cpu().numpy())
                self.rewards[step] = torch.tensor(reward).to(self.device).view(-1)
                next_obs = torch.Tensor(next_obs).to(self.device)
                next_done = torch.Tensor(terminated).to(self.device)
                next_time_out = torch.Tensor(truncated).to(self.device)

                self.calculate_curiosity_rewards(step, next_obs)
                local_step = global_step - 1 * self.args.num_envs
                for idx, d in enumerate(terminated | truncated):
                    local_step+=1
                    if d:
                        avg_returns.append(info["r"][idx])
                        avg_curiosity_reward.append(np.mean(self.curiosity_rewards[step].cpu().numpy()))
                        epi_ret = np.average(avg_returns)
                        epi_cr = np.average(avg_curiosity_reward)
                        epi_suc = np.average([1 if r > 0 else 0 for r in avg_returns])
                        if self.er_counter >= self.av_er_interval:
                            self.er_counter = 0
                            print(
                                f"step={local_step}, {self.av_er_interval}_avg_episodic_return={epi_ret}, curiosity_reward={epi_cr}"
                            )
                            tlol.plot_rnd_er(epi_ret, epi_cr, local_step)
                        else:
                            self.er_counter += 1

                        self.writer.add_scalar("charts/avg_success_rate", epi_suc, local_step)
                        self.writer.add_scalar("charts/avg_episodic_return", epi_ret, local_step)
                        self.writer.add_scalar("charts/episodic_return", info["r"][idx], local_step)
                        self.writer.add_scalar(
                            "charts/episode_curiosity_reward",
                            self.curiosity_rewards[step][idx],
                            local_step,
                        )
                        self.writer.add_scalar("charts/episodic_length", info["l"][idx], local_step)

            curiosity_reward_per_env = np.array(
                [discounted_reward.update(reward_per_step) for reward_per_step in self.curiosity_rewards.cpu().data.numpy().T]
            )
            mean, std, count = (
                np.mean(curiosity_reward_per_env),
                np.std(curiosity_reward_per_env),
                len(curiosity_reward_per_env),
            )
            reward_rms.update_from_moments(mean, std**2, count)

            self.curiosity_rewards /= np.sqrt(reward_rms.var)

            if self.args.value_bootstrap:
                # Value bootstrapping is a technique that reduces the surprise for the critic in case
                # we're ending the episode by timeout. Intuitively, in this case the cumulative return for the last step
                # should not be zero, but rather what the critic expects. This improves learning in many envs
                # because otherwise the critic cannot predict the abrupt change in rewards in a timed-out episode.
                # What we really want here is v(t+1) which we don't have because we don't have obs(t+1) (since
                # the episode ended). Using v(t) is an approximation that requires that rew(t) can be generally ignored.
                self.rewards.add_(self.args.gamma * self.ext_values * self.time_outs)
                self.curiosity_rewards.add_(self.args.int_gamma * self.int_values * self.time_outs)

            # bootstrap value if not done
            with torch.no_grad():
                ext_advantages = self.compute_advantages(next_obs, next_done)
                int_advantages = self.compute_int_advantages(next_obs)
                ext_returns = ext_advantages + self.ext_values
                int_returns = int_advantages + self.int_values

            # flatten the batch
            b_obs = self.obs.reshape((-1,) + self.env.single_observation_space.shape)
            b_logprobs = self.logprobs.reshape(-1)
            b_actions = self.actions.reshape(-1)
            b_ext_advantages = ext_advantages.reshape(-1)
            b_int_advantages = int_advantages.reshape(-1)
            b_ext_returns = ext_returns.reshape(-1)
            b_int_returns = int_returns.reshape(-1)
            b_ext_values = self.ext_values.reshape(-1)

            b_advantages = b_int_advantages * self.args.int_coef + b_ext_advantages * self.args.ext_coef

            self.obs_rms.update(b_obs.cpu().numpy())

            # Optimizing the policy and value network
            b_inds = np.arange(self.args.batch_size)

            rnd_next_obs = (
                (
                    (b_obs - torch.from_numpy(self.obs_rms.mean).to(self.device))
                    / torch.sqrt(torch.from_numpy(self.obs_rms.var).to(self.device))
                ).clip(-5, 5)
            ).float()

            clipfracs = []
            for epoch in range(self.args.update_epochs):
                np.random.shuffle(b_inds)
                for start in range(0, self.args.batch_size, self.args.minibatch_size):
                    end = start + self.args.minibatch_size
                    mb_inds = b_inds[start:end]

                    # Forward loss
                    forward_loss = self.compute_rnd_loss(rnd_next_obs[mb_inds])

                    _, newlogprob, entropy, new_ext_values, new_int_values = self.agent.get_action_and_value(
                        b_obs[mb_inds], b_actions.long()[mb_inds]
                    )
                    logratio = newlogprob - b_logprobs[mb_inds]
                    ratio = logratio.exp()

                    with torch.no_grad():
                        # calculate approx_kl http://joschu.net/blog/kl-approx.html
                        old_approx_kl = (-logratio).mean()
                        approx_kl = ((ratio - 1) - logratio).mean()
                        clipfracs += [((ratio - 1.0).abs() > self.args.clip_coef).float().mean().item()]

                    mb_advantages = b_advantages[mb_inds]
                    if self.args.norm_adv:
                        mb_advantages = (mb_advantages - mb_advantages.mean()) / (mb_advantages.std() + 1e-8)

                    # Policy loss
                    pg_loss = self.compute_policy_loss(mb_advantages, ratio)

                    # Value loss
                    ext_v_loss = self.compute_value_loss(new_ext_values, b_ext_returns[mb_inds])
                    int_v_loss = self.compute_value_loss(new_int_values, b_int_returns[mb_inds])
                    v_loss = ext_v_loss + int_v_loss

                    # Entropy loss
                    entropy_loss = entropy.mean()
                    loss = pg_loss - self.args.ent_coef * entropy_loss + v_loss * self.args.vf_coef + self.args.forward_coef * forward_loss

                    self.optimizer.zero_grad()
                    loss.backward()
                    if self.args.max_grad_norm:
                        nn.utils.clip_grad_norm_(
                            self.combined_parameters,
                            self.args.max_grad_norm,
                        )
                    self.optimizer.step()

                if self.args.target_kl is not None:
                    if approx_kl > self.args.target_kl:
                        break

            # record rewards for plotting purposes
            self.writer.add_scalar("charts/learning_rate", self.optimizer.param_groups[0]["lr"], global_step)
            self.writer.add_scalar("losses/value_loss", v_loss.item(), global_step)
            self.writer.add_scalar("losses/policy_loss", pg_loss.item(), global_step)
            self.writer.add_scalar("losses/entropy", entropy_loss.item(), global_step)
            self.tlol.plot_rnd_loss(entropy_loss.item(), global_step)
            self.writer.add_scalar("losses/old_approx_kl", old_approx_kl.item(), global_step)
            self.writer.add_scalar("losses/fwd_loss", forward_loss.item(), global_step)
            self.writer.add_scalar("losses/approx_kl", approx_kl.item(), global_step)
            # print("SPS:", int(global_step / (time.time() - start_time))) # Uncomment if you want to estimate your training speed - should be around 500 steps per second on Colab
            self.tlol.plot_rnd_sps(int(global_step / (time.time() - start_time)), global_step)
            self.writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

# %%
args = Args(
    num_steps=32,
    num_workers=8,
    num_envs=128,
    env_id="MiniHack-KeyRoom-S5-v0",
    total_timesteps=1_000_000,
    forward_coef=0.1, 
    int_coef=0.1,
    num_iterations_obs_norm_init=50,
)

# %%
args.batch_size = int(args.num_envs * args.num_steps)
args.minibatch_size = int(args.batch_size // args.num_minibatches)
args.num_iterations = args.total_timesteps // args.batch_size
run_name = f"{args.env_id}__rnd__{args.seed}__{int(time.time())}"

writer = SummaryWriter(f"runs/{run_name}")
writer.add_text(
    "hyperparameters",
    "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
)

# seeding
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.backends.cudnn.deterministic = args.torch_deterministic

device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")
env = create_env(args)

agent = Agent(env).to(device)
rnd_model = RNDModel(env).to(device)

trainer = RNDTrainer(args, writer, env, agent, rnd_model, tlol)
trainer.train()

env.close()
writer.close()
# Out:
# Start to initialize observation normalization parameter.....
# End to initialize...
# step=807, 20_avg_episodic_return=0.0, curiosity_reward=180.88967895507812
# step=847, 20_avg_episodic_return=0.0, curiosity_reward=183.4362335205078
# step=879, 20_avg_episodic_return=0.0, curiosity_reward=183.4362335205078
# step=12470, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=76.92489624023438
# step=17374, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=4.857639312744141
# step=23831, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=4.5214128494262695
# step=26509, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=11.48239517211914
# step=26555, 20_avg_episodic_return=0.0, curiosity_reward=25.192169189453125
# step=26601, 20_avg_episodic_return=0.0, curiosity_reward=25.192169189453125
# step=33406, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=15.413836479187012
# step=40590, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=2.774641752243042
# step=44198, 20_avg_episodic_return=0.550000011920929, curiosity_reward=2.7725157737731934
# step=49685, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=2.700587511062622
# step=52244, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=3.5490431785583496
# step=52306, 20_avg_episodic_return=0.0, curiosity_reward=4.989235877990723
# step=54332, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=4.478537559509277
# step=61635, 20_avg_episodic_return=0.5, curiosity_reward=2.2150766849517822
# step=66705, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=1.8733634948730469
# step=70731, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=1.7571903467178345
# step=75287, 20_avg_episodic_return=0.5, curiosity_reward=1.6463005542755127
# step=77972, 20_avg_episodic_return=0.15000000596046448, curiosity_reward=1.64151132106781
# step=78045, 20_avg_episodic_return=0.0, curiosity_reward=1.5784687995910645
# step=82248, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=1.6210826635360718
# step=88197, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=1.3943861722946167
# step=92015, 20_avg_episodic_return=0.550000011920929, curiosity_reward=1.3052971363067627
# step=95646, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=1.230466604232788
# step=100830, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=1.182070016860962
# step=103695, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=1.1139272451400757
# step=104956, 20_avg_episodic_return=0.05000000074505806, curiosity_reward=0.9557524919509888
# step=108647, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=1.0195071697235107
# step=113594, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=0.9343541264533997
# step=117825, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.9157859086990356
# step=121382, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=0.877947986125946
# step=126010, 20_avg_episodic_return=0.5, curiosity_reward=0.8618758916854858
# step=129035, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=0.8839445114135742
# step=129528, 20_avg_episodic_return=0.10000000149011612, curiosity_reward=0.8345258831977844
# step=133557, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.921399712562561
# step=137298, 20_avg_episodic_return=0.5, curiosity_reward=1.162790298461914
# step=141462, 20_avg_episodic_return=0.550000011920929, curiosity_reward=1.1456090211868286
# step=145265, 20_avg_episodic_return=0.5, curiosity_reward=1.026674747467041
# step=148944, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=0.9906086921691895
# step=152369, 20_avg_episodic_return=0.5, curiosity_reward=0.9605957865715027
# step=155142, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=0.953875720500946
# step=156990, 20_avg_episodic_return=0.25, curiosity_reward=0.8909643888473511
# step=160533, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.8842390775680542
# step=163590, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.8063656687736511
# step=167448, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.7482229471206665
# step=171235, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=0.729759931564331
# step=174763, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=0.7496429681777954
# step=177661, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=0.7346484661102295
# step=180706, 20_avg_episodic_return=0.5, curiosity_reward=0.7520478367805481
# step=183452, 20_avg_episodic_return=0.25, curiosity_reward=0.7129408121109009
# step=186319, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.704770028591156
# step=189318, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.6837179064750671
# step=193787, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.6555317044258118
# step=196721, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=0.6741541624069214
# step=200033, 20_avg_episodic_return=0.4000000059604645, curiosity_reward=0.6605128049850464
# step=203614, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.6550797820091248
# step=206434, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.6713122129440308
# step=208909, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.6408165097236633
# step=212078, 20_avg_episodic_return=0.30000001192092896, curiosity_reward=0.6492234468460083
# step=214493, 20_avg_episodic_return=0.3499999940395355, curiosity_reward=0.6952325105667114
# step=218742, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=0.6234215497970581
# step=221183, 20_avg_episodic_return=0.5, curiosity_reward=0.6062331795692444
# step=225183, 20_avg_episodic_return=0.44999998807907104, curiosity_reward=0.5685321092605591
# step=229117, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=0.5411149263381958
# step=232162, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.5282164812088013
# step=234757, 20_avg_episodic_return=0.5, curiosity_reward=0.5325549244880676
# step=237420, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.5596452355384827
# step=240133, 20_avg_episodic_return=0.20000000298023224, curiosity_reward=0.5097963213920593
# step=241930, 20_avg_episodic_return=0.5, curiosity_reward=0.5390415787696838
# step=245398, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.5265764594078064
# step=247401, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.5314605236053467
# step=249358, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=0.5631179809570312
# step=253747, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=0.5502683520317078
# step=256481, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=0.5561690330505371
# step=259104, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.5835331678390503
# step=261679, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.6003055572509766
# step=264167, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.5905828475952148
# step=266303, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.587170422077179
# step=268498, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.577781081199646
# step=271450, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.6002408862113953
# step=274540, 20_avg_episodic_return=0.5, curiosity_reward=0.5983477234840393
# step=276692, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.5860243439674377
# step=279717, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.6112954020500183
# step=282384, 20_avg_episodic_return=0.5, curiosity_reward=0.5721423029899597
# step=285676, 20_avg_episodic_return=0.75, curiosity_reward=0.5295873880386353
# step=288720, 20_avg_episodic_return=0.5, curiosity_reward=0.5150505900382996
# step=291159, 20_avg_episodic_return=0.6499999761581421, curiosity_reward=0.5338544249534607
# step=293072, 20_avg_episodic_return=0.550000011920929, curiosity_reward=0.5573589205741882
# step=295193, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.5693131685256958
# step=297420, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.5281286239624023
# step=299294, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.524802565574646
# step=301309, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.5312197208404541
# step=303317, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.5365341305732727
# step=305730, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.5484462976455688
# step=307377, 20_avg_episodic_return=0.75, curiosity_reward=0.49780815839767456
# step=309845, 20_avg_episodic_return=0.75, curiosity_reward=0.49084120988845825
# step=312509, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.5129840970039368
# step=314727, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.5192760229110718
# step=316972, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.5069551467895508
# step=318847, 20_avg_episodic_return=0.75, curiosity_reward=0.5326001644134521
# step=321611, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.47669583559036255
# step=323285, 20_avg_episodic_return=0.6000000238418579, curiosity_reward=0.4675014913082123
# step=324861, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4953855872154236
# step=327446, 20_avg_episodic_return=0.75, curiosity_reward=0.490770161151886
# step=328780, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.45878228545188904
# step=330874, 20_avg_episodic_return=0.75, curiosity_reward=0.4894203245639801
# step=333092, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.4876246452331543
# step=334800, 20_avg_episodic_return=0.75, curiosity_reward=0.46511325240135193
# step=337036, 20_avg_episodic_return=0.75, curiosity_reward=0.4328554570674896
# step=338692, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.42958641052246094
# step=340507, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4398011565208435
# step=342136, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4093194007873535
# step=344095, 20_avg_episodic_return=0.75, curiosity_reward=0.43369707465171814
# step=346131, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.441377729177475
# step=348248, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.4680563807487488
# step=349739, 20_avg_episodic_return=0.75, curiosity_reward=0.49697238206863403
# step=351491, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5033617615699768
# step=353228, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.5049604177474976
# step=354734, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.5289863348007202
# step=356494, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.5061782598495483
# step=358518, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.46357306838035583
# step=360629, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.4473428726196289
# step=362725, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.47005218267440796
# step=364788, 20_avg_episodic_return=1.0, curiosity_reward=0.4640422463417053
# step=367639, 20_avg_episodic_return=0.75, curiosity_reward=0.43804383277893066
# step=369087, 20_avg_episodic_return=1.0, curiosity_reward=0.4692179560661316
# step=370218, 20_avg_episodic_return=0.75, curiosity_reward=0.42209696769714355
# step=372326, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4240999221801758
# step=374010, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.42946386337280273
# step=375524, 20_avg_episodic_return=0.75, curiosity_reward=0.4443073868751526
# step=376780, 20_avg_episodic_return=0.75, curiosity_reward=0.47985926270484924
# step=378454, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.4366813600063324
# step=380072, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.4280470311641693
# step=381668, 20_avg_episodic_return=0.699999988079071, curiosity_reward=0.41677266359329224
# step=383579, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.43790364265441895
# step=384755, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4341201186180115
# step=386973, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4629055857658386
# step=388235, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4732392728328705
# step=390370, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4394320845603943
# step=391717, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.44792231917381287
# step=393088, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.43582454323768616
# step=394384, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.45606979727745056
# step=395320, 20_avg_episodic_return=0.800000011920929, curiosity_reward=0.4558296799659729
# step=397481, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.46279874444007874
# step=399057, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.48392754793167114
# step=400675, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4699110984802246
# step=401855, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.46417227387428284
# step=402994, 20_avg_episodic_return=1.0, curiosity_reward=0.501296877861023
# step=404397, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.514572262763977
# step=405676, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.5046690106391907
# step=406911, 20_avg_episodic_return=1.0, curiosity_reward=0.4802258610725403
# step=408133, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.4889000356197357
# step=409850, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4543675482273102
# step=411172, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.4706387519836426
# step=412833, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4561963677406311
# step=413892, 20_avg_episodic_return=1.0, curiosity_reward=0.43310388922691345
# step=415132, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.4490510821342468
# step=417046, 20_avg_episodic_return=1.0, curiosity_reward=0.4310302734375
# step=418473, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.43712180852890015
# step=419983, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4448584020137787
# step=421122, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.42928609251976013
# step=422361, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4360751509666443
# step=423814, 20_avg_episodic_return=1.0, curiosity_reward=0.4284009337425232
# step=425127, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4367397427558899
# step=426274, 20_avg_episodic_return=1.0, curiosity_reward=0.4515886902809143
# step=427676, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4660775065422058
# step=429318, 20_avg_episodic_return=0.8500000238418579, curiosity_reward=0.45610809326171875
# step=430273, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.44089213013648987
# step=431574, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.445051908493042
# step=433021, 20_avg_episodic_return=1.0, curiosity_reward=0.43924203515052795
# step=434178, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.45887407660484314
# step=435381, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.43774810433387756
# step=436269, 20_avg_episodic_return=1.0, curiosity_reward=0.4683906137943268
# step=437579, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5436681509017944
# step=438935, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5289665460586548
# step=439738, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5287416577339172
# step=441042, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5317389965057373
# step=442114, 20_avg_episodic_return=1.0, curiosity_reward=0.5149263143539429
# step=443123, 20_avg_episodic_return=1.0, curiosity_reward=0.46550416946411133
# step=444209, 20_avg_episodic_return=1.0, curiosity_reward=0.4841775894165039
# step=445608, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5108634233474731
# step=446669, 20_avg_episodic_return=0.8999999761581421, curiosity_reward=0.5001522898674011
# step=447818, 20_avg_episodic_return=1.0, curiosity_reward=0.4657139182090759
# step=448944, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.46073460578918457
# step=450176, 20_avg_episodic_return=1.0, curiosity_reward=0.4567807614803314
# step=451467, 20_avg_episodic_return=1.0, curiosity_reward=0.4471260607242584
# step=453111, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.45755863189697266
# step=454420, 20_avg_episodic_return=1.0, curiosity_reward=0.4695313572883606
# step=455462, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.46948128938674927
# step=456472, 20_avg_episodic_return=1.0, curiosity_reward=0.46846479177474976
# step=457618, 20_avg_episodic_return=1.0, curiosity_reward=0.48774614930152893
# step=458315, 20_avg_episodic_return=1.0, curiosity_reward=0.4860770106315613
# step=459325, 20_avg_episodic_return=1.0, curiosity_reward=0.4692283570766449
# step=460413, 20_avg_episodic_return=1.0, curiosity_reward=0.467341810464859
# step=461685, 20_avg_episodic_return=1.0, curiosity_reward=0.44359880685806274
# step=462588, 20_avg_episodic_return=1.0, curiosity_reward=0.4426783621311188
# step=463640, 20_avg_episodic_return=1.0, curiosity_reward=0.4527059495449066
# step=464669, 20_avg_episodic_return=1.0, curiosity_reward=0.45817893743515015
# step=465894, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.5037461519241333
# step=466717, 20_avg_episodic_return=1.0, curiosity_reward=0.49806278944015503
# step=467662, 20_avg_episodic_return=1.0, curiosity_reward=0.4741055369377136
# step=468654, 20_avg_episodic_return=1.0, curiosity_reward=0.48205479979515076
# step=469701, 20_avg_episodic_return=1.0, curiosity_reward=0.4956211447715759
# step=470701, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4509366452693939
# step=471638, 20_avg_episodic_return=1.0, curiosity_reward=0.4502022862434387
# step=472535, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4304792881011963
# step=473438, 20_avg_episodic_return=1.0, curiosity_reward=0.45372992753982544
# step=474338, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4552918076515198
# step=475360, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4653831124305725
# step=476188, 20_avg_episodic_return=1.0, curiosity_reward=0.455293744802475
# step=476994, 20_avg_episodic_return=1.0, curiosity_reward=0.43924015760421753
# step=478035, 20_avg_episodic_return=1.0, curiosity_reward=0.4463896155357361
# step=479138, 20_avg_episodic_return=1.0, curiosity_reward=0.4626580774784088
# step=480373, 20_avg_episodic_return=1.0, curiosity_reward=0.4490162432193756
# step=481492, 20_avg_episodic_return=1.0, curiosity_reward=0.45129603147506714
# step=482356, 20_avg_episodic_return=1.0, curiosity_reward=0.4557742178440094
# step=483191, 20_avg_episodic_return=1.0, curiosity_reward=0.47096362709999084
# step=484118, 20_avg_episodic_return=1.0, curiosity_reward=0.460125595331192
# step=485196, 20_avg_episodic_return=1.0, curiosity_reward=0.4672169089317322
# step=486054, 20_avg_episodic_return=1.0, curiosity_reward=0.4973124563694
# step=487194, 20_avg_episodic_return=1.0, curiosity_reward=0.47372788190841675
# step=488378, 20_avg_episodic_return=1.0, curiosity_reward=0.43991026282310486
# step=489411, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.410637229681015
# step=491135, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4044817090034485
# step=491861, 20_avg_episodic_return=1.0, curiosity_reward=0.4265453815460205
# step=492683, 20_avg_episodic_return=1.0, curiosity_reward=0.4301612973213196
# step=493592, 20_avg_episodic_return=1.0, curiosity_reward=0.4124232232570648
# step=494666, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4073112905025482
# step=495316, 20_avg_episodic_return=1.0, curiosity_reward=0.4308578372001648
# step=496702, 20_avg_episodic_return=1.0, curiosity_reward=0.42287006974220276
# step=497922, 20_avg_episodic_return=1.0, curiosity_reward=0.4206465780735016
# step=498959, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.428108274936676
# step=499581, 20_avg_episodic_return=1.0, curiosity_reward=0.4335404932498932
# step=500361, 20_avg_episodic_return=1.0, curiosity_reward=0.40788012742996216
# step=501510, 20_avg_episodic_return=1.0, curiosity_reward=0.41295260190963745
# step=502471, 20_avg_episodic_return=1.0, curiosity_reward=0.41118645668029785
# step=503233, 20_avg_episodic_return=1.0, curiosity_reward=0.46447762846946716
# step=504056, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.48138147592544556
# step=504963, 20_avg_episodic_return=1.0, curiosity_reward=0.46051353216171265
# step=505738, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.47280654311180115
# step=506715, 20_avg_episodic_return=1.0, curiosity_reward=0.44490012526512146
# step=507346, 20_avg_episodic_return=1.0, curiosity_reward=0.4380342364311218
# step=508499, 20_avg_episodic_return=1.0, curiosity_reward=0.4317588210105896
# step=509193, 20_avg_episodic_return=1.0, curiosity_reward=0.42605990171432495
# step=509863, 20_avg_episodic_return=1.0, curiosity_reward=0.4326513409614563
# step=510880, 20_avg_episodic_return=1.0, curiosity_reward=0.42595362663269043
# step=511734, 20_avg_episodic_return=1.0, curiosity_reward=0.41697582602500916
# step=512787, 20_avg_episodic_return=1.0, curiosity_reward=0.4268326163291931
# step=513469, 20_avg_episodic_return=1.0, curiosity_reward=0.3942856192588806
# step=514468, 20_avg_episodic_return=1.0, curiosity_reward=0.36921530961990356
# step=515219, 20_avg_episodic_return=1.0, curiosity_reward=0.38922712206840515
# step=516034, 20_avg_episodic_return=1.0, curiosity_reward=0.38324564695358276
# step=516922, 20_avg_episodic_return=1.0, curiosity_reward=0.3786377012729645
# step=517601, 20_avg_episodic_return=1.0, curiosity_reward=0.3978039026260376
# step=518402, 20_avg_episodic_return=1.0, curiosity_reward=0.4097576141357422
# step=519420, 20_avg_episodic_return=1.0, curiosity_reward=0.39461550116539
# step=520185, 20_avg_episodic_return=1.0, curiosity_reward=0.3655318021774292
# step=521104, 20_avg_episodic_return=1.0, curiosity_reward=0.3738240599632263
# step=522110, 20_avg_episodic_return=1.0, curiosity_reward=0.3873883783817291
# step=522658, 20_avg_episodic_return=1.0, curiosity_reward=0.38540372252464294
# step=523552, 20_avg_episodic_return=1.0, curiosity_reward=0.42615771293640137
# step=524373, 20_avg_episodic_return=1.0, curiosity_reward=0.43536433577537537
# step=525385, 20_avg_episodic_return=1.0, curiosity_reward=0.3785172402858734
# step=526721, 20_avg_episodic_return=1.0, curiosity_reward=0.3549513816833496
# step=527809, 20_avg_episodic_return=1.0, curiosity_reward=0.35959792137145996
# step=528894, 20_avg_episodic_return=1.0, curiosity_reward=0.35542455315589905
# step=529650, 20_avg_episodic_return=1.0, curiosity_reward=0.33838263154029846
# step=530864, 20_avg_episodic_return=1.0, curiosity_reward=0.3411256968975067
# step=531749, 20_avg_episodic_return=1.0, curiosity_reward=0.380803644657135
# step=532856, 20_avg_episodic_return=1.0, curiosity_reward=0.38870158791542053
# step=533825, 20_avg_episodic_return=1.0, curiosity_reward=0.3515416383743286
# step=534629, 20_avg_episodic_return=1.0, curiosity_reward=0.38132092356681824
# step=535642, 20_avg_episodic_return=1.0, curiosity_reward=0.4021926522254944
# step=536510, 20_avg_episodic_return=1.0, curiosity_reward=0.4225987493991852
# step=537221, 20_avg_episodic_return=1.0, curiosity_reward=0.42492207884788513
# step=537958, 20_avg_episodic_return=1.0, curiosity_reward=0.42637816071510315
# step=538988, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4253593385219574
# step=539981, 20_avg_episodic_return=1.0, curiosity_reward=0.4351532459259033
# step=540705, 20_avg_episodic_return=1.0, curiosity_reward=0.43135690689086914
# step=541823, 20_avg_episodic_return=1.0, curiosity_reward=0.4026462435722351
# step=542351, 20_avg_episodic_return=1.0, curiosity_reward=0.376697301864624
# step=543102, 20_avg_episodic_return=1.0, curiosity_reward=0.3804910182952881
# step=544007, 20_avg_episodic_return=1.0, curiosity_reward=0.39321959018707275
# step=544829, 20_avg_episodic_return=1.0, curiosity_reward=0.3945695757865906
# step=545495, 20_avg_episodic_return=1.0, curiosity_reward=0.3840116858482361
# step=545991, 20_avg_episodic_return=1.0, curiosity_reward=0.4339725375175476
# step=547248, 20_avg_episodic_return=1.0, curiosity_reward=0.4141828119754791
# step=547966, 20_avg_episodic_return=1.0, curiosity_reward=0.3906918168067932
# step=548782, 20_avg_episodic_return=1.0, curiosity_reward=0.36996880173683167
# step=549438, 20_avg_episodic_return=1.0, curiosity_reward=0.36017554998397827
# step=550228, 20_avg_episodic_return=1.0, curiosity_reward=0.36571288108825684
# step=551060, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.36700260639190674
# step=551804, 20_avg_episodic_return=1.0, curiosity_reward=0.3637450337409973
# step=552642, 20_avg_episodic_return=1.0, curiosity_reward=0.3433205485343933
# step=553513, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.32252246141433716
# step=554290, 20_avg_episodic_return=1.0, curiosity_reward=0.3489378094673157
# step=554792, 20_avg_episodic_return=1.0, curiosity_reward=0.36042118072509766
# step=555728, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.34530824422836304
# step=556584, 20_avg_episodic_return=1.0, curiosity_reward=0.35256248712539673
# step=557433, 20_avg_episodic_return=1.0, curiosity_reward=0.35190004110336304
# step=558129, 20_avg_episodic_return=1.0, curiosity_reward=0.36663633584976196
# step=558877, 20_avg_episodic_return=1.0, curiosity_reward=0.40386930108070374
# step=559697, 20_avg_episodic_return=1.0, curiosity_reward=0.3781607747077942
# step=560616, 20_avg_episodic_return=1.0, curiosity_reward=0.373665452003479
# step=561656, 20_avg_episodic_return=1.0, curiosity_reward=0.3785346746444702
# step=562306, 20_avg_episodic_return=1.0, curiosity_reward=0.35274776816368103
# step=563353, 20_avg_episodic_return=1.0, curiosity_reward=0.37468811869621277
# step=564146, 20_avg_episodic_return=1.0, curiosity_reward=0.37450966238975525
# step=564907, 20_avg_episodic_return=1.0, curiosity_reward=0.3431757390499115
# step=565800, 20_avg_episodic_return=1.0, curiosity_reward=0.34779301285743713
# step=566674, 20_avg_episodic_return=1.0, curiosity_reward=0.37804022431373596
# step=567496, 20_avg_episodic_return=1.0, curiosity_reward=0.37172871828079224
# step=568130, 20_avg_episodic_return=1.0, curiosity_reward=0.34918212890625
# step=569102, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.3592267632484436
# step=569843, 20_avg_episodic_return=1.0, curiosity_reward=0.367033988237381
# step=570812, 20_avg_episodic_return=1.0, curiosity_reward=0.36964839696884155
# step=571294, 20_avg_episodic_return=1.0, curiosity_reward=0.3708544373512268
# step=571969, 20_avg_episodic_return=1.0, curiosity_reward=0.3990872800350189
# step=572860, 20_avg_episodic_return=1.0, curiosity_reward=0.392925888299942
# step=573287, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.4175024628639221
# step=573993, 20_avg_episodic_return=1.0, curiosity_reward=0.40564900636672974
# step=574959, 20_avg_episodic_return=1.0, curiosity_reward=0.35605889558792114
# step=575939, 20_avg_episodic_return=1.0, curiosity_reward=0.37816572189331055
# step=576556, 20_avg_episodic_return=1.0, curiosity_reward=0.3987666964530945
# step=577239, 20_avg_episodic_return=1.0, curiosity_reward=0.4174310564994812
# step=577818, 20_avg_episodic_return=1.0, curiosity_reward=0.410372793674469
# step=578672, 20_avg_episodic_return=1.0, curiosity_reward=0.35870346426963806
# step=579394, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.34420767426490784
# step=580149, 20_avg_episodic_return=1.0, curiosity_reward=0.36267489194869995
# step=580808, 20_avg_episodic_return=1.0, curiosity_reward=0.35977038741111755
# step=581449, 20_avg_episodic_return=1.0, curiosity_reward=0.36862295866012573
# step=582400, 20_avg_episodic_return=1.0, curiosity_reward=0.3413541316986084
# step=583436, 20_avg_episodic_return=1.0, curiosity_reward=0.3635842800140381
# step=584075, 20_avg_episodic_return=1.0, curiosity_reward=0.38866326212882996
# step=584875, 20_avg_episodic_return=1.0, curiosity_reward=0.40841907262802124
# step=585743, 20_avg_episodic_return=1.0, curiosity_reward=0.4121883809566498
# step=586412, 20_avg_episodic_return=1.0, curiosity_reward=0.39784011244773865
# step=587116, 20_avg_episodic_return=1.0, curiosity_reward=0.3904290199279785
# step=587639, 20_avg_episodic_return=1.0, curiosity_reward=0.3599206507205963
# step=588342, 20_avg_episodic_return=1.0, curiosity_reward=0.35764867067337036
# step=589236, 20_avg_episodic_return=1.0, curiosity_reward=0.342164546251297
# step=590014, 20_avg_episodic_return=1.0, curiosity_reward=0.34356820583343506
# step=590796, 20_avg_episodic_return=1.0, curiosity_reward=0.33537763357162476
# step=591598, 20_avg_episodic_return=1.0, curiosity_reward=0.3095637857913971
# step=592355, 20_avg_episodic_return=1.0, curiosity_reward=0.312880277633667
# step=593086, 20_avg_episodic_return=1.0, curiosity_reward=0.36152535676956177
# step=593581, 20_avg_episodic_return=1.0, curiosity_reward=0.37970972061157227
# step=594339, 20_avg_episodic_return=1.0, curiosity_reward=0.3700371980667114
# step=594897, 20_avg_episodic_return=1.0, curiosity_reward=0.37209877371788025
# step=595646, 20_avg_episodic_return=1.0, curiosity_reward=0.3835121989250183
# step=596115, 20_avg_episodic_return=1.0, curiosity_reward=0.3974170386791229
# step=596776, 20_avg_episodic_return=1.0, curiosity_reward=0.3304736316204071
# step=597675, 20_avg_episodic_return=1.0, curiosity_reward=0.34621262550354004
# step=598185, 20_avg_episodic_return=1.0, curiosity_reward=0.3526274859905243
# step=598852, 20_avg_episodic_return=1.0, curiosity_reward=0.36134788393974304
# step=599403, 20_avg_episodic_return=1.0, curiosity_reward=0.3656681478023529
# step=600140, 20_avg_episodic_return=1.0, curiosity_reward=0.40814024209976196
# step=600654, 20_avg_episodic_return=1.0, curiosity_reward=0.3959980010986328
# step=601430, 20_avg_episodic_return=1.0, curiosity_reward=0.37880730628967285
# step=602174, 20_avg_episodic_return=1.0, curiosity_reward=0.38860806822776794
# step=602861, 20_avg_episodic_return=1.0, curiosity_reward=0.4319291114807129
# step=603555, 20_avg_episodic_return=1.0, curiosity_reward=0.4389610290527344
# step=604340, 20_avg_episodic_return=1.0, curiosity_reward=0.45984402298927307
# step=605124, 20_avg_episodic_return=1.0, curiosity_reward=0.4487174451351166
# step=605761, 20_avg_episodic_return=1.0, curiosity_reward=0.4074938893318176
# step=606664, 20_avg_episodic_return=1.0, curiosity_reward=0.379538357257843
# step=607395, 20_avg_episodic_return=1.0, curiosity_reward=0.3590455949306488
# step=607893, 20_avg_episodic_return=1.0, curiosity_reward=0.39653849601745605
# step=608467, 20_avg_episodic_return=1.0, curiosity_reward=0.4224766790866852
# step=609003, 20_avg_episodic_return=1.0, curiosity_reward=0.399853378534317
# step=609700, 20_avg_episodic_return=1.0, curiosity_reward=0.34551262855529785
# step=610388, 20_avg_episodic_return=1.0, curiosity_reward=0.3299928307533264
# step=611260, 20_avg_episodic_return=1.0, curiosity_reward=0.3412455916404724
# step=611783, 20_avg_episodic_return=1.0, curiosity_reward=0.3511297106742859
# step=612198, 20_avg_episodic_return=1.0, curiosity_reward=0.3568820059299469
# step=612768, 20_avg_episodic_return=1.0, curiosity_reward=0.367084801197052
# step=613391, 20_avg_episodic_return=1.0, curiosity_reward=0.35583043098449707
# step=613967, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.34585434198379517
# step=614532, 20_avg_episodic_return=1.0, curiosity_reward=0.36651429533958435
# step=615187, 20_avg_episodic_return=1.0, curiosity_reward=0.3368866443634033
# step=615864, 20_avg_episodic_return=1.0, curiosity_reward=0.3297150731086731
# step=616579, 20_avg_episodic_return=1.0, curiosity_reward=0.32436224818229675
# step=617293, 20_avg_episodic_return=1.0, curiosity_reward=0.3070988655090332
# step=617923, 20_avg_episodic_return=1.0, curiosity_reward=0.31928059458732605
# step=618413, 20_avg_episodic_return=1.0, curiosity_reward=0.32646024227142334
# step=618953, 20_avg_episodic_return=1.0, curiosity_reward=0.3268384039402008
# step=619495, 20_avg_episodic_return=1.0, curiosity_reward=0.3006361126899719
# step=620510, 20_avg_episodic_return=1.0, curiosity_reward=0.3011433482170105
# step=621167, 20_avg_episodic_return=1.0, curiosity_reward=0.33077308535575867
# step=621673, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.31116801500320435
# step=622372, 20_avg_episodic_return=1.0, curiosity_reward=0.33643007278442383
# step=622796, 20_avg_episodic_return=1.0, curiosity_reward=0.31924766302108765
# step=623618, 20_avg_episodic_return=1.0, curiosity_reward=0.3333534300327301
# step=624049, 20_avg_episodic_return=1.0, curiosity_reward=0.3153652548789978
# step=624751, 20_avg_episodic_return=1.0, curiosity_reward=0.3273635804653168
# step=625424, 20_avg_episodic_return=1.0, curiosity_reward=0.3453613221645355
# step=625885, 20_avg_episodic_return=1.0, curiosity_reward=0.3444906175136566
# step=626592, 20_avg_episodic_return=1.0, curiosity_reward=0.3335598111152649
# step=627149, 20_avg_episodic_return=1.0, curiosity_reward=0.3761237859725952
# step=627830, 20_avg_episodic_return=1.0, curiosity_reward=0.37820738554000854
# step=628483, 20_avg_episodic_return=1.0, curiosity_reward=0.36515146493911743
# step=629289, 20_avg_episodic_return=1.0, curiosity_reward=0.39744246006011963
# step=629818, 20_avg_episodic_return=1.0, curiosity_reward=0.4000980854034424
# step=630413, 20_avg_episodic_return=1.0, curiosity_reward=0.4137650430202484
# step=630955, 20_avg_episodic_return=1.0, curiosity_reward=0.4056475758552551
# step=631603, 20_avg_episodic_return=1.0, curiosity_reward=0.3671031594276428
# step=632306, 20_avg_episodic_return=1.0, curiosity_reward=0.36383193731307983
# step=632924, 20_avg_episodic_return=1.0, curiosity_reward=0.3426263630390167
# step=633579, 20_avg_episodic_return=1.0, curiosity_reward=0.3390059471130371
# step=634439, 20_avg_episodic_return=1.0, curiosity_reward=0.3619692921638489
# step=634910, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.3677257001399994
# step=635518, 20_avg_episodic_return=1.0, curiosity_reward=0.3226006031036377
# step=636171, 20_avg_episodic_return=1.0, curiosity_reward=0.318192720413208
# step=636729, 20_avg_episodic_return=1.0, curiosity_reward=0.30920571088790894
# step=637276, 20_avg_episodic_return=1.0, curiosity_reward=0.30788618326187134
# step=637777, 20_avg_episodic_return=1.0, curiosity_reward=0.3017798364162445
# step=638535, 20_avg_episodic_return=1.0, curiosity_reward=0.31023359298706055
# step=639138, 20_avg_episodic_return=1.0, curiosity_reward=0.330597460269928
# step=639705, 20_avg_episodic_return=1.0, curiosity_reward=0.33194151520729065
# step=640513, 20_avg_episodic_return=1.0, curiosity_reward=0.31826943159103394
# step=641006, 20_avg_episodic_return=1.0, curiosity_reward=0.35732442140579224
# step=641332, 20_avg_episodic_return=1.0, curiosity_reward=0.3729925751686096
# step=641946, 20_avg_episodic_return=1.0, curiosity_reward=0.3327006995677948
# step=642556, 20_avg_episodic_return=1.0, curiosity_reward=0.31688007712364197
# step=643292, 20_avg_episodic_return=1.0, curiosity_reward=0.32749927043914795
# step=643927, 20_avg_episodic_return=1.0, curiosity_reward=0.3109184205532074
# step=644482, 20_avg_episodic_return=1.0, curiosity_reward=0.329534113407135
# step=645072, 20_avg_episodic_return=1.0, curiosity_reward=0.3431534469127655
# step=645633, 20_avg_episodic_return=1.0, curiosity_reward=0.3620866537094116
# step=646218, 20_avg_episodic_return=1.0, curiosity_reward=0.3492685854434967
# step=646861, 20_avg_episodic_return=1.0, curiosity_reward=0.3415217399597168
# step=647458, 20_avg_episodic_return=1.0, curiosity_reward=0.3240002691745758
# step=647925, 20_avg_episodic_return=1.0, curiosity_reward=0.3243970274925232
# step=648484, 20_avg_episodic_return=1.0, curiosity_reward=0.3368709981441498
# step=649140, 20_avg_episodic_return=1.0, curiosity_reward=0.3165457248687744
# step=649755, 20_avg_episodic_return=1.0, curiosity_reward=0.3377295434474945
# step=650247, 20_avg_episodic_return=1.0, curiosity_reward=0.35269245505332947
# step=650723, 20_avg_episodic_return=1.0, curiosity_reward=0.3565920889377594
# step=651456, 20_avg_episodic_return=1.0, curiosity_reward=0.33004695177078247
# step=652217, 20_avg_episodic_return=1.0, curiosity_reward=0.30919328331947327
# step=652776, 20_avg_episodic_return=1.0, curiosity_reward=0.2990152835845947
# step=653227, 20_avg_episodic_return=1.0, curiosity_reward=0.3121170699596405
# step=653847, 20_avg_episodic_return=1.0, curiosity_reward=0.29510846734046936
# step=654295, 20_avg_episodic_return=1.0, curiosity_reward=0.2588256299495697
# step=655085, 20_avg_episodic_return=1.0, curiosity_reward=0.27302974462509155
# step=655687, 20_avg_episodic_return=1.0, curiosity_reward=0.29914984107017517
# step=656124, 20_avg_episodic_return=1.0, curiosity_reward=0.3313440680503845
# step=656492, 20_avg_episodic_return=1.0, curiosity_reward=0.3495115637779236
# step=657017, 20_avg_episodic_return=1.0, curiosity_reward=0.3510425090789795
# step=657448, 20_avg_episodic_return=1.0, curiosity_reward=0.3538743555545807
# step=657976, 20_avg_episodic_return=1.0, curiosity_reward=0.35142722725868225
# step=658652, 20_avg_episodic_return=1.0, curiosity_reward=0.34104812145233154
# step=659134, 20_avg_episodic_return=1.0, curiosity_reward=0.3658461272716522
# step=659597, 20_avg_episodic_return=1.0, curiosity_reward=0.3581011891365051
# step=660442, 20_avg_episodic_return=1.0, curiosity_reward=0.3331632912158966
# step=661012, 20_avg_episodic_return=1.0, curiosity_reward=0.3443341851234436
# step=661763, 20_avg_episodic_return=1.0, curiosity_reward=0.33515530824661255
# step=662230, 20_avg_episodic_return=1.0, curiosity_reward=0.3142220973968506
# step=662872, 20_avg_episodic_return=1.0, curiosity_reward=0.31804159283638
# step=663423, 20_avg_episodic_return=1.0, curiosity_reward=0.3123977780342102
# step=663845, 20_avg_episodic_return=1.0, curiosity_reward=0.3219495713710785
# step=664412, 20_avg_episodic_return=1.0, curiosity_reward=0.3319694995880127
# step=665010, 20_avg_episodic_return=1.0, curiosity_reward=0.31961387395858765
# step=665587, 20_avg_episodic_return=1.0, curiosity_reward=0.3106715679168701
# step=666066, 20_avg_episodic_return=1.0, curiosity_reward=0.3224272131919861
# step=666736, 20_avg_episodic_return=1.0, curiosity_reward=0.34070244431495667
# step=667077, 20_avg_episodic_return=1.0, curiosity_reward=0.3261723816394806
# step=667559, 20_avg_episodic_return=1.0, curiosity_reward=0.3273230791091919
# step=668061, 20_avg_episodic_return=1.0, curiosity_reward=0.31211549043655396
# step=668761, 20_avg_episodic_return=1.0, curiosity_reward=0.32054948806762695
# step=669317, 20_avg_episodic_return=1.0, curiosity_reward=0.32229918241500854
# step=669736, 20_avg_episodic_return=1.0, curiosity_reward=0.3403410017490387
# step=670619, 20_avg_episodic_return=1.0, curiosity_reward=0.3351139724254608
# step=671100, 20_avg_episodic_return=1.0, curiosity_reward=0.328754723072052
# step=671699, 20_avg_episodic_return=1.0, curiosity_reward=0.33145278692245483
# step=672259, 20_avg_episodic_return=1.0, curiosity_reward=0.3196643888950348
# step=672768, 20_avg_episodic_return=1.0, curiosity_reward=0.33598190546035767
# step=673310, 20_avg_episodic_return=1.0, curiosity_reward=0.32055267691612244
# step=673848, 20_avg_episodic_return=1.0, curiosity_reward=0.30861979722976685
# step=674467, 20_avg_episodic_return=1.0, curiosity_reward=0.3142738342285156
# step=674971, 20_avg_episodic_return=1.0, curiosity_reward=0.30966418981552124
# step=675634, 20_avg_episodic_return=1.0, curiosity_reward=0.3101807236671448
# step=676045, 20_avg_episodic_return=1.0, curiosity_reward=0.33412590622901917
# step=676528, 20_avg_episodic_return=1.0, curiosity_reward=0.33236226439476013
# step=677241, 20_avg_episodic_return=1.0, curiosity_reward=0.3554818630218506
# step=677668, 20_avg_episodic_return=1.0, curiosity_reward=0.3338000774383545
# step=678233, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.3349542021751404
# step=678677, 20_avg_episodic_return=1.0, curiosity_reward=0.34316831827163696
# step=679270, 20_avg_episodic_return=1.0, curiosity_reward=0.3396470546722412
# step=679709, 20_avg_episodic_return=1.0, curiosity_reward=0.3452683985233307
# step=680433, 20_avg_episodic_return=1.0, curiosity_reward=0.3472786545753479
# step=680831, 20_avg_episodic_return=1.0, curiosity_reward=0.33717846870422363
# step=681310, 20_avg_episodic_return=1.0, curiosity_reward=0.3356481194496155
# step=682019, 20_avg_episodic_return=1.0, curiosity_reward=0.3422115445137024
# step=682613, 20_avg_episodic_return=1.0, curiosity_reward=0.36258983612060547
# step=683119, 20_avg_episodic_return=1.0, curiosity_reward=0.37286195158958435
# step=683566, 20_avg_episodic_return=1.0, curiosity_reward=0.3594810366630554
# step=684136, 20_avg_episodic_return=1.0, curiosity_reward=0.3558090925216675
# step=684732, 20_avg_episodic_return=1.0, curiosity_reward=0.34247392416000366
# step=685194, 20_avg_episodic_return=1.0, curiosity_reward=0.34050121903419495
# step=685685, 20_avg_episodic_return=1.0, curiosity_reward=0.38531509041786194
# step=686109, 20_avg_episodic_return=1.0, curiosity_reward=0.3749234676361084
# step=686867, 20_avg_episodic_return=1.0, curiosity_reward=0.35316112637519836
# step=687358, 20_avg_episodic_return=1.0, curiosity_reward=0.3878071904182434
# step=687832, 20_avg_episodic_return=1.0, curiosity_reward=0.4015072286128998
# step=688249, 20_avg_episodic_return=1.0, curiosity_reward=0.38508230447769165
# step=688816, 20_avg_episodic_return=1.0, curiosity_reward=0.37273675203323364
# step=689278, 20_avg_episodic_return=1.0, curiosity_reward=0.3477157950401306
# step=689954, 20_avg_episodic_return=1.0, curiosity_reward=0.37261638045310974
# step=690495, 20_avg_episodic_return=1.0, curiosity_reward=0.3580305576324463
# step=690946, 20_avg_episodic_return=1.0, curiosity_reward=0.33971473574638367
# step=691624, 20_avg_episodic_return=1.0, curiosity_reward=0.34134918451309204
# step=692085, 20_avg_episodic_return=1.0, curiosity_reward=0.3642250597476959
# step=692439, 20_avg_episodic_return=1.0, curiosity_reward=0.3803125321865082
# step=692994, 20_avg_episodic_return=1.0, curiosity_reward=0.3712288737297058
# step=693587, 20_avg_episodic_return=1.0, curiosity_reward=0.3836519122123718
# step=694020, 20_avg_episodic_return=1.0, curiosity_reward=0.3636661171913147
# step=694551, 20_avg_episodic_return=1.0, curiosity_reward=0.38439875841140747
# step=695013, 20_avg_episodic_return=1.0, curiosity_reward=0.3454521596431732
# step=695518, 20_avg_episodic_return=1.0, curiosity_reward=0.37397369742393494
# step=696036, 20_avg_episodic_return=1.0, curiosity_reward=0.3946494460105896
# step=696389, 20_avg_episodic_return=1.0, curiosity_reward=0.3875562250614166
# step=697073, 20_avg_episodic_return=1.0, curiosity_reward=0.36948949098587036
# step=697693, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.3730565011501312
# step=698107, 20_avg_episodic_return=1.0, curiosity_reward=0.40773677825927734
# step=698600, 20_avg_episodic_return=1.0, curiosity_reward=0.38773879408836365
# step=699083, 20_avg_episodic_return=1.0, curiosity_reward=0.38583803176879883
# step=699609, 20_avg_episodic_return=1.0, curiosity_reward=0.37663906812667847
# step=700080, 20_avg_episodic_return=1.0, curiosity_reward=0.3796085715293884
# step=700705, 20_avg_episodic_return=1.0, curiosity_reward=0.35211434960365295
# step=701246, 20_avg_episodic_return=1.0, curiosity_reward=0.3541758954524994
# step=701717, 20_avg_episodic_return=1.0, curiosity_reward=0.38694295287132263
# step=702233, 20_avg_episodic_return=1.0, curiosity_reward=0.36667388677597046
# step=702857, 20_avg_episodic_return=1.0, curiosity_reward=0.36080583930015564
# step=703229, 20_avg_episodic_return=1.0, curiosity_reward=0.38439279794692993
# step=703743, 20_avg_episodic_return=1.0, curiosity_reward=0.3769803047180176
# step=704150, 20_avg_episodic_return=1.0, curiosity_reward=0.36050957441329956
# step=704658, 20_avg_episodic_return=1.0, curiosity_reward=0.3516541123390198
# step=705154, 20_avg_episodic_return=1.0, curiosity_reward=0.35008880496025085
# step=705585, 20_avg_episodic_return=1.0, curiosity_reward=0.3489072918891907
# step=706039, 20_avg_episodic_return=1.0, curiosity_reward=0.33195480704307556
# step=706717, 20_avg_episodic_return=1.0, curiosity_reward=0.3146444261074066
# step=707259, 20_avg_episodic_return=1.0, curiosity_reward=0.31108155846595764
# step=707635, 20_avg_episodic_return=1.0, curiosity_reward=0.334955632686615
# step=708089, 20_avg_episodic_return=1.0, curiosity_reward=0.3313593864440918
# step=708631, 20_avg_episodic_return=1.0, curiosity_reward=0.31824183464050293
# step=709110, 20_avg_episodic_return=1.0, curiosity_reward=0.3338172435760498
# step=709794, 20_avg_episodic_return=1.0, curiosity_reward=0.3274010121822357
# step=710254, 20_avg_episodic_return=1.0, curiosity_reward=0.3296813666820526
# step=710582, 20_avg_episodic_return=1.0, curiosity_reward=0.3461320102214813
# step=711077, 20_avg_episodic_return=1.0, curiosity_reward=0.3386986255645752
# step=711763, 20_avg_episodic_return=1.0, curiosity_reward=0.3438488245010376
# step=712170, 20_avg_episodic_return=1.0, curiosity_reward=0.37508535385131836
# step=712543, 20_avg_episodic_return=1.0, curiosity_reward=0.3483542501926422
# step=713048, 20_avg_episodic_return=1.0, curiosity_reward=0.33097043633461
# step=713459, 20_avg_episodic_return=1.0, curiosity_reward=0.28635525703430176
# step=713896, 20_avg_episodic_return=1.0, curiosity_reward=0.32081374526023865
# step=714515, 20_avg_episodic_return=1.0, curiosity_reward=0.3080245852470398
# step=715118, 20_avg_episodic_return=1.0, curiosity_reward=0.29825329780578613
# step=715747, 20_avg_episodic_return=1.0, curiosity_reward=0.31352248787879944
# step=716194, 20_avg_episodic_return=1.0, curiosity_reward=0.32479384541511536
# step=716568, 20_avg_episodic_return=1.0, curiosity_reward=0.3020320534706116
# step=717129, 20_avg_episodic_return=1.0, curiosity_reward=0.3238615393638611
# step=717700, 20_avg_episodic_return=1.0, curiosity_reward=0.31487196683883667
# step=718231, 20_avg_episodic_return=1.0, curiosity_reward=0.32736334204673767
# step=718631, 20_avg_episodic_return=1.0, curiosity_reward=0.3278943598270416
# step=719002, 20_avg_episodic_return=1.0, curiosity_reward=0.3332424461841583
# step=719470, 20_avg_episodic_return=1.0, curiosity_reward=0.33781522512435913
# step=720146, 20_avg_episodic_return=1.0, curiosity_reward=0.34261375665664673
# step=720654, 20_avg_episodic_return=1.0, curiosity_reward=0.33168476819992065
# step=721110, 20_avg_episodic_return=1.0, curiosity_reward=0.33836573362350464
# step=721604, 20_avg_episodic_return=1.0, curiosity_reward=0.3687964975833893
# step=722233, 20_avg_episodic_return=1.0, curiosity_reward=0.3525809347629547
# step=722564, 20_avg_episodic_return=1.0, curiosity_reward=0.3352542817592621
# step=722991, 20_avg_episodic_return=1.0, curiosity_reward=0.31626686453819275
# step=723681, 20_avg_episodic_return=1.0, curiosity_reward=0.33531755208969116
# step=724208, 20_avg_episodic_return=1.0, curiosity_reward=0.3512217104434967
# step=724734, 20_avg_episodic_return=1.0, curiosity_reward=0.363089919090271
# step=725090, 20_avg_episodic_return=1.0, curiosity_reward=0.35596004128456116
# step=725467, 20_avg_episodic_return=1.0, curiosity_reward=0.3637255132198334
# step=726064, 20_avg_episodic_return=1.0, curiosity_reward=0.3710159659385681
# step=726551, 20_avg_episodic_return=1.0, curiosity_reward=0.35909736156463623
# step=726964, 20_avg_episodic_return=1.0, curiosity_reward=0.35695046186447144
# step=727529, 20_avg_episodic_return=1.0, curiosity_reward=0.36152464151382446
# step=728022, 20_avg_episodic_return=1.0, curiosity_reward=0.39939001202583313
# step=728291, 20_avg_episodic_return=1.0, curiosity_reward=0.41336989402770996
# step=728805, 20_avg_episodic_return=1.0, curiosity_reward=0.3903900682926178
# ...
# step=914834, 20_avg_episodic_return=1.0, curiosity_reward=0.30982813239097595
# step=915233, 20_avg_episodic_return=1.0, curiosity_reward=0.3080287575721741
# step=915694, 20_avg_episodic_return=1.0, curiosity_reward=0.3404947817325592
# step=916148, 20_avg_episodic_return=1.0, curiosity_reward=0.33503034710884094
# step=916598, 20_avg_episodic_return=1.0, curiosity_reward=0.3568160831928253
# step=916885, 20_avg_episodic_return=1.0, curiosity_reward=0.38211044669151306
# step=917390, 20_avg_episodic_return=1.0, curiosity_reward=0.3446362316608429
# step=917853, 20_avg_episodic_return=1.0, curiosity_reward=0.3241020143032074
# step=918272, 20_avg_episodic_return=1.0, curiosity_reward=0.3484227657318115
# step=918609, 20_avg_episodic_return=1.0, curiosity_reward=0.30883246660232544
# step=919111, 20_avg_episodic_return=1.0, curiosity_reward=0.31716594099998474
# step=919463, 20_avg_episodic_return=1.0, curiosity_reward=0.3451041281223297
# step=919899, 20_avg_episodic_return=1.0, curiosity_reward=0.35240572690963745
# step=920285, 20_avg_episodic_return=1.0, curiosity_reward=0.33967214822769165
# step=920821, 20_avg_episodic_return=1.0, curiosity_reward=0.30654579401016235
# step=921255, 20_avg_episodic_return=1.0, curiosity_reward=0.32980379462242126
# step=921629, 20_avg_episodic_return=1.0, curiosity_reward=0.35851678252220154
# step=922038, 20_avg_episodic_return=1.0, curiosity_reward=0.35137125849723816
# step=922461, 20_avg_episodic_return=1.0, curiosity_reward=0.32723069190979004
# step=922726, 20_avg_episodic_return=1.0, curiosity_reward=0.33827564120292664
# step=923128, 20_avg_episodic_return=1.0, curiosity_reward=0.33713895082473755
# step=923522, 20_avg_episodic_return=1.0, curiosity_reward=0.3515143394470215
# step=923940, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.3373672664165497
# step=924390, 20_avg_episodic_return=1.0, curiosity_reward=0.3274824023246765
# step=924762, 20_avg_episodic_return=1.0, curiosity_reward=0.3253384828567505
# step=925122, 20_avg_episodic_return=1.0, curiosity_reward=0.34924522042274475
# step=925419, 20_avg_episodic_return=1.0, curiosity_reward=0.33037644624710083
# step=926125, 20_avg_episodic_return=1.0, curiosity_reward=0.32269102334976196
# step=926370, 20_avg_episodic_return=1.0, curiosity_reward=0.3338065445423126
# step=926682, 20_avg_episodic_return=1.0, curiosity_reward=0.35872310400009155
# step=927188, 20_avg_episodic_return=1.0, curiosity_reward=0.30756136775016785
# step=927627, 20_avg_episodic_return=1.0, curiosity_reward=0.33169880509376526
# step=927968, 20_avg_episodic_return=1.0, curiosity_reward=0.31097525358200073
# step=928335, 20_avg_episodic_return=1.0, curiosity_reward=0.3334152400493622
# step=928858, 20_avg_episodic_return=1.0, curiosity_reward=0.3511344790458679
# step=929271, 20_avg_episodic_return=1.0, curiosity_reward=0.3661887049674988
# step=929635, 20_avg_episodic_return=1.0, curiosity_reward=0.36929139494895935
# step=930013, 20_avg_episodic_return=1.0, curiosity_reward=0.32765993475914
# step=930454, 20_avg_episodic_return=1.0, curiosity_reward=0.32256683707237244
# step=931017, 20_avg_episodic_return=1.0, curiosity_reward=0.3260186016559601
# step=931306, 20_avg_episodic_return=1.0, curiosity_reward=0.31185585260391235
# step=931746, 20_avg_episodic_return=1.0, curiosity_reward=0.32774052023887634
# step=932207, 20_avg_episodic_return=1.0, curiosity_reward=0.3336857855319977
# step=932657, 20_avg_episodic_return=1.0, curiosity_reward=0.30701467394828796
# step=933055, 20_avg_episodic_return=1.0, curiosity_reward=0.3305441737174988
# step=933519, 20_avg_episodic_return=1.0, curiosity_reward=0.34048783779144287
# step=933870, 20_avg_episodic_return=1.0, curiosity_reward=0.3199574649333954
# step=934219, 20_avg_episodic_return=1.0, curiosity_reward=0.31620699167251587
# step=934564, 20_avg_episodic_return=1.0, curiosity_reward=0.30142155289649963
# step=935200, 20_avg_episodic_return=1.0, curiosity_reward=0.29205793142318726
# step=935652, 20_avg_episodic_return=1.0, curiosity_reward=0.36710605025291443
# step=935924, 20_avg_episodic_return=1.0, curiosity_reward=0.33125633001327515
# step=936158, 20_avg_episodic_return=1.0, curiosity_reward=0.36160191893577576
# step=936586, 20_avg_episodic_return=1.0, curiosity_reward=0.36029574275016785
# step=937070, 20_avg_episodic_return=1.0, curiosity_reward=0.3215290606021881
# step=937478, 20_avg_episodic_return=1.0, curiosity_reward=0.3094617426395416
# step=938040, 20_avg_episodic_return=1.0, curiosity_reward=0.3209487497806549
# step=938401, 20_avg_episodic_return=1.0, curiosity_reward=0.3255098760128021
# step=938757, 20_avg_episodic_return=1.0, curiosity_reward=0.3290151059627533
# step=939194, 20_avg_episodic_return=1.0, curiosity_reward=0.31914153695106506
# step=939491, 20_avg_episodic_return=1.0, curiosity_reward=0.3491297662258148
# step=939869, 20_avg_episodic_return=1.0, curiosity_reward=0.3378601670265198
# step=940325, 20_avg_episodic_return=1.0, curiosity_reward=0.33189812302589417
# step=940946, 20_avg_episodic_return=1.0, curiosity_reward=0.29964572191238403
# step=941373, 20_avg_episodic_return=1.0, curiosity_reward=0.3130446672439575
# step=941770, 20_avg_episodic_return=1.0, curiosity_reward=0.3298698365688324
# step=942178, 20_avg_episodic_return=1.0, curiosity_reward=0.33969947695732117
# step=942572, 20_avg_episodic_return=1.0, curiosity_reward=0.29793378710746765
# step=942896, 20_avg_episodic_return=1.0, curiosity_reward=0.31644704937934875
# step=943282, 20_avg_episodic_return=1.0, curiosity_reward=0.31763553619384766
# step=943805, 20_avg_episodic_return=1.0, curiosity_reward=0.3328707814216614
# step=944124, 20_avg_episodic_return=1.0, curiosity_reward=0.30979031324386597
# step=944485, 20_avg_episodic_return=1.0, curiosity_reward=0.35547736287117004
# step=944912, 20_avg_episodic_return=1.0, curiosity_reward=0.3539067804813385
# step=945340, 20_avg_episodic_return=1.0, curiosity_reward=0.32303380966186523
# step=945725, 20_avg_episodic_return=1.0, curiosity_reward=0.3294500410556793
# step=946085, 20_avg_episodic_return=1.0, curiosity_reward=0.3131653666496277
# step=946530, 20_avg_episodic_return=1.0, curiosity_reward=0.3056674301624298
# step=947031, 20_avg_episodic_return=1.0, curiosity_reward=0.305319219827652
# step=947470, 20_avg_episodic_return=1.0, curiosity_reward=0.3138379156589508
# step=947895, 20_avg_episodic_return=1.0, curiosity_reward=0.3190456032752991
# step=948216, 20_avg_episodic_return=1.0, curiosity_reward=0.31537967920303345
# step=948695, 20_avg_episodic_return=1.0, curiosity_reward=0.32202860713005066
# step=949228, 20_avg_episodic_return=1.0, curiosity_reward=0.31404799222946167
# step=949664, 20_avg_episodic_return=1.0, curiosity_reward=0.317877858877182
# step=949985, 20_avg_episodic_return=1.0, curiosity_reward=0.3310067355632782
# step=950400, 20_avg_episodic_return=1.0, curiosity_reward=0.3513964116573334
# step=950746, 20_avg_episodic_return=1.0, curiosity_reward=0.34266576170921326
# step=951165, 20_avg_episodic_return=1.0, curiosity_reward=0.32698559761047363
# step=951593, 20_avg_episodic_return=1.0, curiosity_reward=0.31204932928085327
# step=952089, 20_avg_episodic_return=1.0, curiosity_reward=0.30457809567451477
# step=952583, 20_avg_episodic_return=1.0, curiosity_reward=0.3120482563972473
# step=953073, 20_avg_episodic_return=1.0, curiosity_reward=0.31502094864845276
# step=953387, 20_avg_episodic_return=1.0, curiosity_reward=0.32642725110054016
# step=953775, 20_avg_episodic_return=1.0, curiosity_reward=0.3326267898082733
# step=954300, 20_avg_episodic_return=1.0, curiosity_reward=0.335480272769928
# step=954645, 20_avg_episodic_return=1.0, curiosity_reward=0.36089247465133667
# step=954953, 20_avg_episodic_return=1.0, curiosity_reward=0.317943274974823
# step=955418, 20_avg_episodic_return=1.0, curiosity_reward=0.3301061987876892
# step=955876, 20_avg_episodic_return=1.0, curiosity_reward=0.34643983840942383
# step=956296, 20_avg_episodic_return=1.0, curiosity_reward=0.38837242126464844
# step=956589, 20_avg_episodic_return=1.0, curiosity_reward=0.36072567105293274
# step=956996, 20_avg_episodic_return=1.0, curiosity_reward=0.3695649802684784
# step=957363, 20_avg_episodic_return=1.0, curiosity_reward=0.3204182982444763
# step=958076, 20_avg_episodic_return=1.0, curiosity_reward=0.34471312165260315
# step=958383, 20_avg_episodic_return=1.0, curiosity_reward=0.33444157242774963
# step=958751, 20_avg_episodic_return=1.0, curiosity_reward=0.38588231801986694
# step=959190, 20_avg_episodic_return=1.0, curiosity_reward=0.36234959959983826
# step=959462, 20_avg_episodic_return=1.0, curiosity_reward=0.31958240270614624
# step=960008, 20_avg_episodic_return=1.0, curiosity_reward=0.32038614153862
# step=960336, 20_avg_episodic_return=1.0, curiosity_reward=0.32698720693588257
# step=960755, 20_avg_episodic_return=1.0, curiosity_reward=0.3605843782424927
# step=961126, 20_avg_episodic_return=1.0, curiosity_reward=0.36397165060043335
# step=961584, 20_avg_episodic_return=1.0, curiosity_reward=0.3533462882041931
# step=962042, 20_avg_episodic_return=1.0, curiosity_reward=0.3518404960632324
# step=962502, 20_avg_episodic_return=1.0, curiosity_reward=0.35104185342788696
# step=962755, 20_avg_episodic_return=1.0, curiosity_reward=0.35227495431900024
# step=963146, 20_avg_episodic_return=1.0, curiosity_reward=0.3593318462371826
# step=963708, 20_avg_episodic_return=1.0, curiosity_reward=0.3157321512699127
# step=964216, 20_avg_episodic_return=1.0, curiosity_reward=0.3300386667251587
# step=964567, 20_avg_episodic_return=1.0, curiosity_reward=0.36369839310646057
# step=964859, 20_avg_episodic_return=1.0, curiosity_reward=0.3415341079235077
# step=965239, 20_avg_episodic_return=1.0, curiosity_reward=0.3293253779411316
# step=965705, 20_avg_episodic_return=1.0, curiosity_reward=0.3362290859222412
# step=966053, 20_avg_episodic_return=1.0, curiosity_reward=0.3438717722892761
# step=966474, 20_avg_episodic_return=1.0, curiosity_reward=0.3549860119819641
# step=966871, 20_avg_episodic_return=1.0, curiosity_reward=0.34238195419311523
# step=967284, 20_avg_episodic_return=1.0, curiosity_reward=0.3644769787788391
# step=967658, 20_avg_episodic_return=1.0, curiosity_reward=0.36519894003868103
# step=967939, 20_avg_episodic_return=1.0, curiosity_reward=0.3411257863044739
# step=968484, 20_avg_episodic_return=1.0, curiosity_reward=0.37561047077178955
# step=968892, 20_avg_episodic_return=1.0, curiosity_reward=0.3653048276901245
# step=969260, 20_avg_episodic_return=1.0, curiosity_reward=0.3494979739189148
# step=969544, 20_avg_episodic_return=1.0, curiosity_reward=0.3485476076602936
# step=969987, 20_avg_episodic_return=1.0, curiosity_reward=0.3424672484397888
# step=970360, 20_avg_episodic_return=1.0, curiosity_reward=0.336853951215744
# step=970849, 20_avg_episodic_return=0.949999988079071, curiosity_reward=0.3267431855201721
# step=971196, 20_avg_episodic_return=1.0, curiosity_reward=0.33542677760124207
# step=971697, 20_avg_episodic_return=1.0, curiosity_reward=0.34945160150527954
# step=972158, 20_avg_episodic_return=1.0, curiosity_reward=0.34056657552719116
# step=972497, 20_avg_episodic_return=1.0, curiosity_reward=0.3441379964351654
# step=972780, 20_avg_episodic_return=1.0, curiosity_reward=0.36284297704696655
# step=973143, 20_avg_episodic_return=1.0, curiosity_reward=0.350318044424057
# step=973633, 20_avg_episodic_return=1.0, curiosity_reward=0.3578612804412842
# step=974106, 20_avg_episodic_return=1.0, curiosity_reward=0.3282991051673889
# step=974550, 20_avg_episodic_return=1.0, curiosity_reward=0.3345854878425598
# step=974929, 20_avg_episodic_return=1.0, curiosity_reward=0.3626070022583008
# step=975219, 20_avg_episodic_return=1.0, curiosity_reward=0.3777015805244446
# step=975591, 20_avg_episodic_return=1.0, curiosity_reward=0.37369459867477417
# step=976020, 20_avg_episodic_return=1.0, curiosity_reward=0.3497399389743805
# step=976535, 20_avg_episodic_return=1.0, curiosity_reward=0.31706327199935913
# step=977038, 20_avg_episodic_return=1.0, curiosity_reward=0.31918883323669434
# step=977456, 20_avg_episodic_return=1.0, curiosity_reward=0.3566116392612457
# step=977924, 20_avg_episodic_return=1.0, curiosity_reward=0.33624783158302307
# step=978238, 20_avg_episodic_return=1.0, curiosity_reward=0.3584107756614685
# step=978613, 20_avg_episodic_return=1.0, curiosity_reward=0.3492371141910553
# step=979115, 20_avg_episodic_return=1.0, curiosity_reward=0.314444899559021
# step=979546, 20_avg_episodic_return=1.0, curiosity_reward=0.3436691462993622
# step=979951, 20_avg_episodic_return=1.0, curiosity_reward=0.3571186661720276
# step=980444, 20_avg_episodic_return=1.0, curiosity_reward=0.3439183235168457
# step=980764, 20_avg_episodic_return=1.0, curiosity_reward=0.3217698931694031
# step=981298, 20_avg_episodic_return=1.0, curiosity_reward=0.31480544805526733
# step=981735, 20_avg_episodic_return=1.0, curiosity_reward=0.30165109038352966
# step=982206, 20_avg_episodic_return=1.0, curiosity_reward=0.33327680826187134
# step=982576, 20_avg_episodic_return=1.0, curiosity_reward=0.37817519903182983
# step=982837, 20_avg_episodic_return=1.0, curiosity_reward=0.38267213106155396
# step=983193, 20_avg_episodic_return=1.0, curiosity_reward=0.3619001507759094
# step=983796, 20_avg_episodic_return=1.0, curiosity_reward=0.35459280014038086
# step=984187, 20_avg_episodic_return=1.0, curiosity_reward=0.35709673166275024
# step=984578, 20_avg_episodic_return=1.0, curiosity_reward=0.37860721349716187
# step=985045, 20_avg_episodic_return=1.0, curiosity_reward=0.34319591522216797
# step=985514, 20_avg_episodic_return=1.0, curiosity_reward=0.35820701718330383
# step=985846, 20_avg_episodic_return=1.0, curiosity_reward=0.37300220131874084
# step=986240, 20_avg_episodic_return=1.0, curiosity_reward=0.3853273391723633
# step=986573, 20_avg_episodic_return=1.0, curiosity_reward=0.38596111536026
# step=986893, 20_avg_episodic_return=1.0, curiosity_reward=0.3736700713634491
# step=987470, 20_avg_episodic_return=1.0, curiosity_reward=0.3677821457386017
# step=987979, 20_avg_episodic_return=1.0, curiosity_reward=0.4049855172634125
# step=988216, 20_avg_episodic_return=1.0, curiosity_reward=0.3998691141605377
# step=988536, 20_avg_episodic_return=1.0, curiosity_reward=0.4188978672027588
# step=988847, 20_avg_episodic_return=1.0, curiosity_reward=0.4189671576023102
# step=989332, 20_avg_episodic_return=1.0, curiosity_reward=0.38952773809432983
# step=989760, 20_avg_episodic_return=1.0, curiosity_reward=0.4104915261268616
# step=990112, 20_avg_episodic_return=1.0, curiosity_reward=0.41251903772354126
# step=990545, 20_avg_episodic_return=1.0, curiosity_reward=0.40925392508506775
# step=990982, 20_avg_episodic_return=1.0, curiosity_reward=0.3859728276729584
# step=991322, 20_avg_episodic_return=1.0, curiosity_reward=0.3993174433708191
# step=991575, 20_avg_episodic_return=1.0, curiosity_reward=0.412442147731781
# step=992044, 20_avg_episodic_return=1.0, curiosity_reward=0.3956502079963684
# step=992683, 20_avg_episodic_return=1.0, curiosity_reward=0.3794258236885071
# step=992930, 20_avg_episodic_return=1.0, curiosity_reward=0.44453325867652893
# step=993194, 20_avg_episodic_return=1.0, curiosity_reward=0.4500856399536133
# step=993780, 20_avg_episodic_return=1.0, curiosity_reward=0.37649622559547424
# step=994195, 20_avg_episodic_return=1.0, curiosity_reward=0.3877750635147095
# step=994618, 20_avg_episodic_return=1.0, curiosity_reward=0.3850477635860443
# step=995065, 20_avg_episodic_return=1.0, curiosity_reward=0.36356720328330994
# step=995413, 20_avg_episodic_return=1.0, curiosity_reward=0.392731249332428
# step=995827, 20_avg_episodic_return=1.0, curiosity_reward=0.43198147416114807
# step=996239, 20_avg_episodic_return=1.0, curiosity_reward=0.4147220551967621
# step=996615, 20_avg_episodic_return=1.0, curiosity_reward=0.41703638434410095
# step=997133, 20_avg_episodic_return=1.0, curiosity_reward=0.395355761051178
# step=997537, 20_avg_episodic_return=1.0, curiosity_reward=0.38994187116622925
# step=997963, 20_avg_episodic_return=1.0, curiosity_reward=0.40317869186401367
# step=998335, 20_avg_episodic_return=1.0, curiosity_reward=0.4146144986152649
# step=998714, 20_avg_episodic_return=1.0, curiosity_reward=0.3944924771785736
# step=999138, 20_avg_episodic_return=1.0, curiosity_reward=0.3940148949623108

# %% [markdown]
# ## Visualizing Curiosity Reward in PPO with RND
#
# In this section, we focus on analyzing the curiosity-driven exploration of the agent while solving an episode. The **curiosity reward**, a key component in the Random Network Distillation (RND) algorithm, measures how "novel" or "unpredictable" a state is to the agent. This intrinsic reward helps guide exploration in environments where external rewards are sparse or absent.
#
# ### Key Visualizations:
# 1. **Curiosity Reward vs. Steps**:
#    - The chart displays the trend of curiosity rewards across steps during an episode. It provides insights into how the agent encounters and evaluates novel states, highlighting periods of high novelty in model activity.
#
# 2. **High-Scoring States**:
#    - Below the plot, showcase images of the environmental states that resulted in the highest curiosity rewards. These snapshots offer a glimpse into the scenarios the agent found most novel or unpredictable, such as first appearance, revealing a new room, or having part of the view obstructed by a wall.

# %%
@torch.no_grad
def play(agent, args, rnd_model:RNDModel, obs_rms_mean, obs_rms_std):
    env = env_creator(args)
    env = VideoRecorder(env, ".")
    device = next(agent.parameters()).device
    obs, info = env.reset()

    frames_scores = []

    steps = 0
    reward = 0.0
    total_reward = 0.0

    while True:
        obs_norm = (
            (
                (torch.Tensor(obs).to(device) - torch.from_numpy(obs_rms_mean).to(device))
                / torch.sqrt(torch.from_numpy(obs_rms_std).to(device))
            ).clip(-5, 5)
        ).float()
        predict_next_feature, target_next_feature = rnd_model(obs_norm)
        steps_curiosity_rewards = ((target_next_feature - predict_next_feature).pow(2).sum(1) / 2).data
        frames_scores.append(steps_curiosity_rewards.item())

        action = agent.get_action_and_value(torch.Tensor(obs).unsqueeze(0).to(device))[0][0].item()
        obs, reward, terminated, truncated, info = env.step(action)

        steps += 1
        total_reward += reward

        if not (terminated or truncated):
            continue

        break
    print(f"reward: {reward}, steps: {steps}")
    env.close()
    return info, env._frames, frames_scores

_, frames, frames_scores = play(agent, args, rnd_model, trainer.obs_rms.mean, trainer.obs_rms.var)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 430) to (608, 432) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# reward: 1.0, steps: 15
# [swscaler @ 0x4002b640] Warning: data is not aligned! This can lead to a speed loss

# %%
import heapq

unique_scores = list(set(frames_scores))
top_scores = heapq.nlargest(6, unique_scores)
intresting_frames_ixs = set()
for score in top_scores:
    indices_with_score = [ix for ix, val in enumerate(frames_scores) if val == score]
    intresting_frames_ixs.update(indices_with_score)
intresting_frames_ixs = list(intresting_frames_ixs)
intresting_frames_ixs.sort()

selected_frames = []
selected_scores = []
for ix in intresting_frames_ixs:
    selected_frames.append(frames[ix])
    selected_scores.append(frames_scores[ix])

images = selected_frames

descriptions = [
    f"Step: {fix}, Curiosity reward: {round(sc, 4)}" for (fix, sc) in zip(intresting_frames_ixs, selected_scores)
]

fig, axes = plt.subplots(2, 3, figsize=(20, 10))
axes = axes.flatten()
for ax, img, desc in zip(axes, images, descriptions):
    ax.imshow(img)
    ax.axis('off')
    ax.set_title(desc, fontsize=10)

plt.tight_layout()
plt.show()

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(list(range(len(frames_scores))), frames_scores, marker='o', linestyle='-', color='b', label='Frame Scores')
plt.title('Curiosity reward across episode completion')
plt.xlabel('Step')
plt.ylabel('Curiosity reward')
plt.grid(True)
plt.legend()
plt.show()

# %%
Video("trajectory.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
tlol.save_static_plots_in_notebook()
# Below charts that will be saved into notebook for solution evaluation
# IMPORTANT TIP - when training, there is a small chance that ppo will outperform ppo+rnd
